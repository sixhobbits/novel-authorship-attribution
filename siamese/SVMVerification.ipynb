# %%
import os
import numpy as np
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import FeatureUnion

from collections import Counter
from sklearn.metrics import classification_report, accuracy_score, f1_score

from statistics import mean

# %%
datadir = "/data/panstuffs/"
# - english
pan15train = "pan15-authorship-verification-training-dataset-english-2015-04-19/"
pan15test = "pan15-authorship-verification-test-dataset2-english-2015-04-19/"

pan14traine = "pan14-author-verification-training-corpus-english-essays-2014-04-22/"
pan14teste = "pan14-author-verification-test-corpus2-english-essays-2014-04-22/"

pan14trainn = "pan14-author-verification-training-corpus-english-novels-2014-04-22/"
pan14testn = "pan14-author-verification-test-corpus2-english-novels-2014-04-22/"


# 
pan15traindutch = "pan15-authorship-verification-training-dataset-dutch-2015-04-19/"
pan15testdutch = "pan15-authorship-verification-test-dataset2-dutch-2015-04-19/"

pan15traingreek = "pan15-authorship-verification-training-dataset-greek-2015-04-19/"
pan15testgreek = "pan15-authorship-verification-test-dataset2-greek-2015-04-19/"

pan15trainspanish = "pan15-authorship-verification-training-dataset-spanish-2015-04-19/"
pan15testspanish = "pan15-authorship-verification-test-dataset2-spanish-2015-04-19/"

# - other
pan14traindutchr = "pan14-author-verification-training-corpus-dutch-essays-2014-04-22/"
pan14testdutchr = "pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/"

pan14traindutche = "pan14-author-verification-training-corpus-dutch-essays-2014-04-22/"
pan14testdutche = "pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/"

pan14traingreek = "pan14-author-verification-training-corpus-greek-articles-2014-04-22/"
pan14testgreek = "pan14-author-verification-test-corpus2-greek-articles-2014-04-22/"

pan14trainspanish = "pan14-author-verification-training-corpus-spanish-articles-2014-04-22/"
pan14testspanish = "pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/"

# %%
def read_file(filepath):
    with open(filepath) as f:
        s = f.read()
    return s

def load_pan_data(directory, prefix=None):
    """Load known and unknown texts in the PAN data format"""
    # FIXME: assumes one known file per author, which is fine for English datasets only
    authors = sorted([x for x in os.listdir(directory) if not "." in x])  # ignore hidden stuff and files with extension
    known_texts = []
    unknown_texts = []
    for author in authors:
        authordir = os.path.join(directory, author)
        kfs = [x for x in os.listdir(authordir) if x.startswith("known")]
        all_known = ""
        for fn in kfs:
            kf = os.path.join(authordir, fn)
            all_known += "{}\n".format(read_file(kf))  
        uf = os.path.join(directory, author, "unknown.txt")
        known_texts.append(all_known)
        unknown_texts.append(read_file(uf))
        
    truthfile = os.path.join(directory, "truth.txt")
    with open(truthfile) as f:
        lines = f.read().strip().split("\n")
    y = [1 if line.split()[1] == "Y" else 0 for line in lines]
    y = np.array(y)
    return known_texts, unknown_texts, y

def get_fit_vectorizer(knowns, unknowns):
    char_tf = TfidfVectorizer(analyzer='char', ngram_range=(2,3), min_df=0.01, lowercase=False)
    word_tf = TfidfVectorizer(ngram_range=(1,2), lowercase=False, min_df=0.01)
    vectorizer = FeatureUnion([
        ('char', char_tf),
        ('word', word_tf)
    ])

    vectorizer.fit(knowns + unknowns)
    return vectorizer

def vectorize(knowns, unknowns, vectorizer):
    known_vecs = vectorizer.transform(knowns)
    unknown_vecs = vectorizer.transform(unknowns)
    pairs = np.abs(known_vecs - unknown_vecs)
    return pairs

# %%
def run_experiment(train_dir, test_dir):
    print("__RUNNING ON {} {}".format(train_dir, test_dir))
    tr_known, tr_unknown, tr_labels = load_pan_data(datadir + train_dir)
    te_known, te_unknown, te_labels = load_pan_data(datadir + test_dir) 
    
    vectorizer = get_fit_vectorizer(tr_known, tr_unknown)
    
    train_pairs = vectorize(tr_known, tr_unknown, vectorizer)
    test_pairs = vectorize(te_known, te_unknown, vectorizer)
    
    svm = LinearSVC()
    svm.fit(train_pairs, tr_labels)
    
    preds = svm.predict(test_pairs)
    cls_report = classification_report(te_labels, preds)
    acc = accuracy_score(te_labels, preds)
    print(cls_report)
    print(acc)
    return cls_report, acc

# %%
report, acc = run_experiment(pan15train, pan15test)
# Out:
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.78      0.66       250
#           1       0.65      0.40      0.50       250
#
# avg / total       0.61      0.59      0.58       500
#
# 0.592

# %%
datasets = """
pan15train = "pan15-authorship-verification-training-dataset-english-2015-04-19/"
pan15test = "pan15-authorship-verification-test-dataset2-english-2015-04-19/"
pan14traine = "pan14-author-verification-training-corpus-english-essays-2014-04-22/"
pan14teste = "pan14-author-verification-test-corpus2-english-essays-2014-04-22/"
pan14trainn = "pan14-author-verification-training-corpus-english-novels-2014-04-22/"
pan14testn = "pan14-author-verification-test-corpus2-english-novels-2014-04-22/"
pan15traindutch = "pan15-authorship-verification-training-dataset-dutch-2015-04-19/"
pan15testdutch = "pan15-authorship-verification-test-dataset2-dutch-2015-04-19/"
pan15traingreek = "pan15-authorship-verification-training-dataset-greek-2015-04-19/"
pan15testgreek = "pan15-authorship-verification-test-dataset2-greek-2015-04-19/"
pan15trainspanish = "pan15-authorship-verification-training-dataset-spanish-2015-04-19/"
pan15testspanish = "pan15-authorship-verification-test-dataset2-spanish-2015-04-19/"
pan14traindutchr = "pan14-author-verification-training-corpus-dutch-essays-2014-04-22/"
pan14testdutchr = "pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/"
pan14traindutche = "pan14-author-verification-training-corpus-dutch-essays-2014-04-22/"
pan14testdutche = "pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/"
pan14traingreek = "pan14-author-verification-training-corpus-greek-articles-2014-04-22/"
pan14testgreek = "pan14-author-verification-test-corpus2-greek-articles-2014-04-22/"
pan14trainspanish = "pan14-author-verification-training-corpus-spanish-articles-2014-04-22/"
pan14testspanish = "pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/"
""".split("\n")[1:21]

# %%
dataset_pairs = []
for i in range(0, len(datasets), 2):
    train = datasets[i].split(" = ")[1].replace('"',"")
    test = datasets[i+1].split(" = ")[1].replace('"', "")
    dataset_pairs.append((train, test))

# %%
results = {}
for train, test in dataset_pairs:
    results["train: {}, test: {}".format(train, test)] = run_experiment(train, test)
    results["train: {}, test: {}".format(test, train)] = run_experiment(test, train)
# Out:
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.78      0.66       250
#           1       0.65      0.40      0.50       250
#
# avg / total       0.61      0.59      0.58       500
#
# 0.592
# __RUNNING ON pan15-authorship-verification-test-dataset2-english-2015-04-19/ pan15-authorship-verification-training-dataset-english-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.88      0.69        50
#           1       0.74      0.34      0.47        50
#
# avg / total       0.66      0.61      0.58       100
#
# 0.61
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.57      0.63      0.60       100
#           1       0.59      0.53      0.56       100
#
# avg / total       0.58      0.58      0.58       200
#
# 0.58
# __RUNNING ON pan14-author-verification-test-corpus2-english-essays-2014-04-22/ pan14-author-verification-training-corpus-english-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.60      0.64      0.62       100
#           1       0.62      0.58      0.60       100
#
# avg / total       0.61      0.61      0.61       200
#
# 0.61
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.72      0.46      0.56       100
#           1       0.60      0.82      0.69       100
#
# avg / total       0.66      0.64      0.63       200
#
# 0.64
# __RUNNING ON pan14-author-verification-test-corpus2-english-novels-2014-04-22/ pan14-author-verification-training-corpus-english-novels-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.71      0.74      0.73        50
#           1       0.73      0.70      0.71        50
#
# avg / total       0.72      0.72      0.72       100
#
# 0.72
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.68      0.52      0.59        82
#           1       0.62      0.76      0.68        83
#
# avg / total       0.65      0.64      0.64       165
#
# 0.642424242424
# __RUNNING ON pan15-authorship-verification-test-dataset2-dutch-2015-04-19/ pan15-authorship-verification-training-dataset-dutch-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.78      0.58      0.67        50
#           1       0.67      0.84      0.74        50
#
# avg / total       0.73      0.71      0.71       100
#
# 0.71
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.54      0.56        50
#           1       0.57      0.60      0.58        50
#
# avg / total       0.57      0.57      0.57       100
#
# 0.57
# __RUNNING ON pan15-authorship-verification-test-dataset2-greek-2015-04-19/ pan15-authorship-verification-training-dataset-greek-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.56      0.86      0.68        50
#           1       0.70      0.32      0.44        50
#
# avg / total       0.63      0.59      0.56       100
#
# 0.59
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.52      1.00      0.68        50
#           1       1.00      0.08      0.15        50
#
# avg / total       0.76      0.54      0.42       100
#
# 0.54
# __RUNNING ON pan15-authorship-verification-test-dataset2-spanish-2015-04-19/ pan15-authorship-verification-training-dataset-spanish-2015-04-19/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        50
#           1       0.00      0.00      0.00        50
#
# avg / total       0.25      0.50      0.33       100
#
# 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# 0.52
# __RUNNING ON pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/ pan14-author-verification-training-corpus-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.67      0.50      0.57        48
#           1       0.60      0.75      0.67        48
#
# avg / total       0.63      0.62      0.62        96
#
# 0.625
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.66      0.65      0.65        48
#           1       0.65      0.67      0.66        48
#
# avg / total       0.66      0.66      0.66        96
#
# 0.65625
# __RUNNING ON pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/ pan14-author-verification-training-corpus-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.71      0.62      0.67        48
#           1       0.67      0.75      0.71        48
#
# avg / total       0.69      0.69      0.69        96
#
# 0.6875
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.51      0.80      0.62        50
#           1       0.52      0.22      0.31        50
#
# avg / total       0.52      0.51      0.47       100
#
# 0.51
# __RUNNING ON pan14-author-verification-test-corpus2-greek-articles-2014-04-22/ pan14-author-verification-training-corpus-greek-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.53      0.34      0.41        50
#           1       0.51      0.70      0.59        50
#
# avg / total       0.52      0.52      0.50       100
#
# 0.52
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.88      0.44      0.59        50
#           1       0.63      0.94      0.75        50
#
# avg / total       0.75      0.69      0.67       100
#
# 0.69
# __RUNNING ON pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/ pan14-author-verification-training-corpus-spanish-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.75      0.42      0.54        50
#           1       0.60      0.86      0.70        50
#
# avg / total       0.67      0.64      0.62       100
#
# 0.64

# %%
for key in results:
    print(key)
    print(results[key][0])
    print(results[key][1])
    print("---------")
# Out:
# train: pan15-authorship-verification-training-dataset-english-2015-04-19/, test: pan15-authorship-verification-test-dataset2-english-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.78      0.66       250
#           1       0.65      0.40      0.50       250
#
# avg / total       0.61      0.59      0.58       500
#
# 0.592
# ---------
# train: pan15-authorship-verification-test-dataset2-english-2015-04-19/, test: pan15-authorship-verification-training-dataset-english-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.88      0.69        50
#           1       0.74      0.34      0.47        50
#
# avg / total       0.66      0.61      0.58       100
#
# 0.61
# ---------
# train: pan14-author-verification-training-corpus-english-essays-2014-04-22/, test: pan14-author-verification-test-corpus2-english-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.57      0.63      0.60       100
#           1       0.59      0.53      0.56       100
#
# avg / total       0.58      0.58      0.58       200
#
# 0.58
# ---------
# train: pan14-author-verification-test-corpus2-english-essays-2014-04-22/, test: pan14-author-verification-training-corpus-english-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.60      0.64      0.62       100
#           1       0.62      0.58      0.60       100
#
# avg / total       0.61      0.61      0.61       200
#
# 0.61
# ---------
# train: pan14-author-verification-training-corpus-english-novels-2014-04-22/, test: pan14-author-verification-test-corpus2-english-novels-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.72      0.46      0.56       100
#           1       0.60      0.82      0.69       100
#
# avg / total       0.66      0.64      0.63       200
#
# 0.64
# ---------
# train: pan14-author-verification-test-corpus2-english-novels-2014-04-22/, test: pan14-author-verification-training-corpus-english-novels-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.71      0.74      0.73        50
#           1       0.73      0.70      0.71        50
#
# avg / total       0.72      0.72      0.72       100
#
# 0.72
# ---------
# train: pan15-authorship-verification-training-dataset-dutch-2015-04-19/, test: pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.68      0.52      0.59        82
#           1       0.62      0.76      0.68        83
#
# avg / total       0.65      0.64      0.64       165
#
# 0.642424242424
# ---------
# train: pan15-authorship-verification-test-dataset2-dutch-2015-04-19/, test: pan15-authorship-verification-training-dataset-dutch-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.78      0.58      0.67        50
#           1       0.67      0.84      0.74        50
#
# avg / total       0.73      0.71      0.71       100
#
# 0.71
# ---------
# train: pan15-authorship-verification-training-dataset-greek-2015-04-19/, test: pan15-authorship-verification-test-dataset2-greek-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.57      0.54      0.56        50
#           1       0.57      0.60      0.58        50
#
# avg / total       0.57      0.57      0.57       100
#
# 0.57
# ---------
# train: pan15-authorship-verification-test-dataset2-greek-2015-04-19/, test: pan15-authorship-verification-training-dataset-greek-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.56      0.86      0.68        50
#           1       0.70      0.32      0.44        50
#
# avg / total       0.63      0.59      0.56       100
#
# 0.59
# ---------
# train: pan15-authorship-verification-training-dataset-spanish-2015-04-19/, test: pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.52      1.00      0.68        50
#           1       1.00      0.08      0.15        50
#
# avg / total       0.76      0.54      0.42       100
#
# 0.54
# ---------
# train: pan15-authorship-verification-test-dataset2-spanish-2015-04-19/, test: pan15-authorship-verification-training-dataset-spanish-2015-04-19/
#              precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        50
#           1       0.00      0.00      0.00        50
#
# avg / total       0.25      0.50      0.33       100
#
# 0.5
# ---------
# train: pan14-author-verification-training-corpus-dutch-essays-2014-04-22/, test: pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# 0.52
# ---------
# train: pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/, test: pan14-author-verification-training-corpus-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.67      0.50      0.57        48
#           1       0.60      0.75      0.67        48
#
# avg / total       0.63      0.62      0.62        96
#
# 0.625
# ---------
# train: pan14-author-verification-training-corpus-dutch-essays-2014-04-22/, test: pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.66      0.65      0.65        48
#           1       0.65      0.67      0.66        48
#
# avg / total       0.66      0.66      0.66        96
#
# 0.65625
# ---------
# train: pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/, test: pan14-author-verification-training-corpus-dutch-essays-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.71      0.62      0.67        48
#           1       0.67      0.75      0.71        48
#
# avg / total       0.69      0.69      0.69        96
#
# 0.6875
# ---------
# train: pan14-author-verification-training-corpus-greek-articles-2014-04-22/, test: pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.51      0.80      0.62        50
#           1       0.52      0.22      0.31        50
#
# avg / total       0.52      0.51      0.47       100
#
# 0.51
# ---------
# train: pan14-author-verification-test-corpus2-greek-articles-2014-04-22/, test: pan14-author-verification-training-corpus-greek-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.53      0.34      0.41        50
#           1       0.51      0.70      0.59        50
#
# avg / total       0.52      0.52      0.50       100
#
# 0.52
# ---------
# train: pan14-author-verification-training-corpus-spanish-articles-2014-04-22/, test: pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.88      0.44      0.59        50
#           1       0.63      0.94      0.75        50
#
# avg / total       0.75      0.69      0.67       100
#
# 0.69
# ---------
# train: pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/, test: pan14-author-verification-training-corpus-spanish-articles-2014-04-22/
#              precision    recall  f1-score   support
#
#           0       0.75      0.42      0.54        50
#           1       0.60      0.86      0.70        50
#
# avg / total       0.67      0.64      0.62       100
#
# 0.64
# ---------

# %%
# %%time
for train, test in dataset_pairs:
    run_experiment_n_times(train, test, 10)
# Out:
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 370, 0: 130})
#              precision    recall  f1-score   support
#
#           0       0.91      0.47      0.62       250
#           1       0.64      0.95      0.77       250
#
# avg / total       0.78      0.71      0.69       500
#
# Accuracy 0.712
# Counter({1: 60, 0: 40})
#              precision    recall  f1-score   support
#
#           0       0.85      0.68      0.76        50
#           1       0.73      0.88      0.80        50
#
# avg / total       0.79      0.78      0.78       100
#
# Accuracy 0.78
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 390, 0: 110})
#              precision    recall  f1-score   support
#
#           0       0.87      0.38      0.53       250
#           1       0.61      0.94      0.74       250
#
# avg / total       0.74      0.66      0.64       500
#
# Accuracy 0.664
# Counter({1: 60, 0: 40})
#              precision    recall  f1-score   support
#
#           0       0.82      0.66      0.73        50
#           1       0.72      0.86      0.78        50
#
# avg / total       0.77      0.76      0.76       100
#
# Accuracy 0.76
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 358, 0: 142})
#              precision    recall  f1-score   support
#
#           0       0.94      0.53      0.68       250
#           1       0.67      0.96      0.79       250
#
# avg / total       0.80      0.75      0.74       500
#
# Accuracy 0.748
# Counter({1: 55, 0: 45})
#              precision    recall  f1-score   support
#
#           0       0.87      0.78      0.82        50
#           1       0.80      0.88      0.84        50
#
# avg / total       0.83      0.83      0.83       100
#
# Accuracy 0.83
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 382, 0: 118})
#              precision    recall  f1-score   support
#
#           0       0.91      0.43      0.58       250
#           1       0.63      0.96      0.76       250
#
# avg / total       0.77      0.69      0.67       500
#
# Accuracy 0.692
# Counter({1: 52, 0: 48})
#              precision    recall  f1-score   support
#
#           0       0.85      0.82      0.84        50
#           1       0.83      0.86      0.84        50
#
# avg / total       0.84      0.84      0.84       100
#
# Accuracy 0.84
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 359, 0: 141})
#              precision    recall  f1-score   support
#
#           0       0.91      0.52      0.66       250
#           1       0.66      0.95      0.78       250
#
# avg / total       0.79      0.73      0.72       500
#
# Accuracy 0.734
# Counter({1: 51, 0: 49})
#              precision    recall  f1-score   support
#
#           0       0.88      0.86      0.87        50
#           1       0.86      0.88      0.87        50
#
# avg / total       0.87      0.87      0.87       100
#
# Accuracy 0.87
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 419, 0: 81})
#              precision    recall  f1-score   support
#
#           0       0.99      0.32      0.48       250
#           1       0.59      1.00      0.74       250
#
# avg / total       0.79      0.66      0.61       500
#
# Accuracy 0.658
# Counter({0: 55, 1: 45})
#              precision    recall  f1-score   support
#
#           0       0.76      0.84      0.80        50
#           1       0.82      0.74      0.78        50
#
# avg / total       0.79      0.79      0.79       100
#
# Accuracy 0.79
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 411, 0: 89})
#              precision    recall  f1-score   support
#
#           0       0.83      0.30      0.44       250
#           1       0.57      0.94      0.71       250
#
# avg / total       0.70      0.62      0.57       500
#
# Accuracy 0.618
# Counter({1: 67, 0: 33})
#              precision    recall  f1-score   support
#
#           0       0.94      0.62      0.75        50
#           1       0.72      0.96      0.82        50
#
# avg / total       0.83      0.79      0.78       100
#
# Accuracy 0.79
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 393, 0: 107})
#              precision    recall  f1-score   support
#
#           0       0.79      0.34      0.47       250
#           1       0.58      0.91      0.71       250
#
# avg / total       0.68      0.62      0.59       500
#
# Accuracy 0.622
# Counter({1: 53, 0: 47})
#              precision    recall  f1-score   support
#
#           0       0.87      0.82      0.85        50
#           1       0.83      0.88      0.85        50
#
# avg / total       0.85      0.85      0.85       100
#
# Accuracy 0.85
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 402, 0: 98})
#              precision    recall  f1-score   support
#
#           0       0.91      0.36      0.51       250
#           1       0.60      0.96      0.74       250
#
# avg / total       0.75      0.66      0.63       500
#
# Accuracy 0.66
# Counter({1: 51, 0: 49})
#              precision    recall  f1-score   support
#
#           0       0.78      0.76      0.77        50
#           1       0.76      0.78      0.77        50
#
# avg / total       0.77      0.77      0.77       100
#
# Accuracy 0.77
# __RUNNING ON pan15-authorship-verification-training-dataset-english-2015-04-19/ pan15-authorship-verification-test-dataset2-english-2015-04-19/
# Counter({1: 369, 0: 131})
#              precision    recall  f1-score   support
#
#           0       0.95      0.50      0.66       250
#           1       0.66      0.98      0.79       250
#
# avg / total       0.81      0.74      0.72       500
#
# Accuracy 0.738
# Counter({1: 53, 0: 47})
#              precision    recall  f1-score   support
#
#           0       0.94      0.88      0.91        50
#           1       0.89      0.94      0.91        50
#
# avg / total       0.91      0.91      0.91       100
#
# Accuracy 0.91
# test: [0.69439728353140917, 0.63541666666666652, 0.73566729323308278, 0.66892542652724263, 0.72072787135843841, 0.61388915231734242, 0.57381102200563183, 0.58832677705607905, 0.62537902827727243, 0.72226815751423645]
# test avg: 0.6578808678487402
# train: [0.7777777777777779, 0.75757575757575757, 0.82957393483709274, 0.83993597438975587, 0.86998699869987006, 0.78947368421052633, 0.78375038616002468, 0.84986487839055158, 0.76997699769976991, 0.90991892703433086]
# train avg: 0.8177835316775457
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 136, 0: 64})
#              precision    recall  f1-score   support
#
#           0       0.56      0.36      0.44       100
#           1       0.53      0.72      0.61       100
#
# avg / total       0.55      0.54      0.52       200
#
# Accuracy 0.54
# Counter({1: 154, 0: 46})
#              precision    recall  f1-score   support
#
#           0       0.50      0.23      0.32       100
#           1       0.50      0.77      0.61       100
#
# avg / total       0.50      0.50      0.46       200
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 123, 0: 77})
#              precision    recall  f1-score   support
#
#           0       0.53      0.41      0.46       100
#           1       0.52      0.64      0.57       100
#
# avg / total       0.53      0.53      0.52       200
#
# Accuracy 0.525
# Counter({1: 129, 0: 71})
#              precision    recall  f1-score   support
#
#           0       0.51      0.36      0.42       100
#           1       0.50      0.65      0.57       100
#
# avg / total       0.51      0.51      0.49       200
#
# Accuracy 0.505
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 153, 0: 47})
#              precision    recall  f1-score   support
#
#           0       0.53      0.25      0.34       100
#           1       0.51      0.78      0.62       100
#
# avg / total       0.52      0.52      0.48       200
#
# Accuracy 0.515
# Counter({1: 147, 0: 53})
#              precision    recall  f1-score   support
#
#           0       0.47      0.25      0.33       100
#           1       0.49      0.72      0.58       100
#
# avg / total       0.48      0.48      0.45       200
#
# Accuracy 0.485
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 121, 0: 79})
#              precision    recall  f1-score   support
#
#           0       0.62      0.49      0.55       100
#           1       0.58      0.70      0.63       100
#
# avg / total       0.60      0.59      0.59       200
#
# Accuracy 0.595
# Counter({1: 147, 0: 53})
#              precision    recall  f1-score   support
#
#           0       0.45      0.24      0.31       100
#           1       0.48      0.71      0.57       100
#
# avg / total       0.47      0.47      0.44       200
#
# Accuracy 0.475
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 178, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.55      0.12      0.20       100
#           1       0.51      0.90      0.65       100
#
# avg / total       0.53      0.51      0.42       200
#
# Accuracy 0.51
# Counter({1: 131, 0: 69})
#              precision    recall  f1-score   support
#
#           0       0.58      0.40      0.47       100
#           1       0.54      0.71      0.61       100
#
# avg / total       0.56      0.56      0.54       200
#
# Accuracy 0.555
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({0: 108, 1: 92})
#              precision    recall  f1-score   support
#
#           0       0.57      0.62      0.60       100
#           1       0.59      0.54      0.56       100
#
# avg / total       0.58      0.58      0.58       200
#
# Accuracy 0.58
# Counter({1: 149, 0: 51})
#              precision    recall  f1-score   support
#
#           0       0.47      0.24      0.32       100
#           1       0.49      0.73      0.59       100
#
# avg / total       0.48      0.48      0.45       200
#
# Accuracy 0.485
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 141, 0: 59})
#              precision    recall  f1-score   support
#
#           0       0.49      0.29      0.36       100
#           1       0.50      0.70      0.58       100
#
# avg / total       0.49      0.49      0.47       200
#
# Accuracy 0.495
# Counter({1: 112, 0: 88})
#              precision    recall  f1-score   support
#
#           0       0.58      0.51      0.54       100
#           1       0.56      0.63      0.59       100
#
# avg / total       0.57      0.57      0.57       200
#
# Accuracy 0.57
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({0: 114, 1: 86})
#              precision    recall  f1-score   support
#
#           0       0.54      0.62      0.58       100
#           1       0.56      0.48      0.52       100
#
# avg / total       0.55      0.55      0.55       200
#
# Accuracy 0.55
# Counter({1: 126, 0: 74})
#              precision    recall  f1-score   support
#
#           0       0.51      0.38      0.44       100
#           1       0.51      0.64      0.57       100
#
# avg / total       0.51      0.51      0.50       200
#
# Accuracy 0.51
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 131, 0: 69})
#              precision    recall  f1-score   support
#
#           0       0.65      0.45      0.53       100
#           1       0.58      0.76      0.66       100
#
# avg / total       0.62      0.60      0.60       200
#
# Accuracy 0.605
# Counter({1: 155, 0: 45})
#              precision    recall  f1-score   support
#
#           0       0.47      0.21      0.29       100
#           1       0.49      0.76      0.60       100
#
# avg / total       0.48      0.48      0.44       200
#
# Accuracy 0.485
# __RUNNING ON pan14-author-verification-training-corpus-english-essays-2014-04-22/ pan14-author-verification-test-corpus2-english-essays-2014-04-22/
# Counter({1: 191, 0: 9})
#              precision    recall  f1-score   support
#
#           0       0.33      0.03      0.06       100
#           1       0.49      0.94      0.65       100
#
# avg / total       0.41      0.48      0.35       200
#
# Accuracy 0.485
# Counter({1: 134, 0: 66})
#              precision    recall  f1-score   support
#
#           0       0.56      0.37      0.45       100
#           1       0.53      0.71      0.61       100
#
# avg / total       0.55      0.54      0.53       200
#
# Accuracy 0.54
# test: [0.52459694088466302, 0.51863393377416334, 0.47836842246780131, 0.59048509820774031, 0.42210166293194951, 0.57932692307692313, 0.47284636864218799, 0.54778414229725647, 0.59527651835344142, 0.3505469907626344]
# test avg: 0.5079967001398761
# train: [0.4606838528745551, 0.49436911054929911, 0.45489666851895949, 0.44431213781058987, 0.54404569789185175, 0.4521130881140456, 0.56844640706543559, 0.50157664530566581, 0.44286680189317107, 0.52631036968386358]
# train avg: 0.4889620779707437
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 170, 0: 30})
#              precision    recall  f1-score   support
#
#           0       1.00      0.30      0.46       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.79      0.65      0.60       200
#
# Accuracy 0.65
# Counter({1: 60, 0: 40})
#              precision    recall  f1-score   support
#
#           0       0.72      0.58      0.64        50
#           1       0.65      0.78      0.71        50
#
# avg / total       0.69      0.68      0.68       100
#
# Accuracy 0.68
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 181, 0: 19})
#              precision    recall  f1-score   support
#
#           0       1.00      0.19      0.32       100
#           1       0.55      1.00      0.71       100
#
# avg / total       0.78      0.59      0.52       200
#
# Accuracy 0.595
# Counter({1: 64, 0: 36})
#              precision    recall  f1-score   support
#
#           0       0.81      0.58      0.67        50
#           1       0.67      0.86      0.75        50
#
# avg / total       0.74      0.72      0.71       100
#
# Accuracy 0.72
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 170, 0: 30})
#              precision    recall  f1-score   support
#
#           0       1.00      0.30      0.46       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.79      0.65      0.60       200
#
# Accuracy 0.65
# Counter({1: 59, 0: 41})
#              precision    recall  f1-score   support
#
#           0       0.76      0.62      0.68        50
#           1       0.68      0.80      0.73        50
#
# avg / total       0.72      0.71      0.71       100
#
# Accuracy 0.71
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 173, 0: 27})
#              precision    recall  f1-score   support
#
#           0       1.00      0.27      0.43       100
#           1       0.58      1.00      0.73       100
#
# avg / total       0.79      0.64      0.58       200
#
# Accuracy 0.635
# Counter({1: 73, 0: 27})
#              precision    recall  f1-score   support
#
#           0       0.74      0.40      0.52        50
#           1       0.59      0.86      0.70        50
#
# avg / total       0.66      0.63      0.61       100
#
# Accuracy 0.63
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 169, 0: 31})
#              precision    recall  f1-score   support
#
#           0       1.00      0.31      0.47       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.80      0.66      0.61       200
#
# Accuracy 0.655
# Counter({1: 67, 0: 33})
#              precision    recall  f1-score   support
#
#           0       0.79      0.52      0.63        50
#           1       0.64      0.86      0.74        50
#
# avg / total       0.71      0.69      0.68       100
#
# Accuracy 0.69
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 170, 0: 30})
#              precision    recall  f1-score   support
#
#           0       1.00      0.30      0.46       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.79      0.65      0.60       200
#
# Accuracy 0.65
# Counter({1: 64, 0: 36})
#              precision    recall  f1-score   support
#
#           0       0.67      0.48      0.56        50
#           1       0.59      0.76      0.67        50
#
# avg / total       0.63      0.62      0.61       100
#
# Accuracy 0.62
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 172, 0: 28})
#              precision    recall  f1-score   support
#
#           0       1.00      0.28      0.44       100
#           1       0.58      1.00      0.74       100
#
# avg / total       0.79      0.64      0.59       200
#
# Accuracy 0.64
# Counter({1: 78, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.68      0.30      0.42        50
#           1       0.55      0.86      0.67        50
#
# avg / total       0.62      0.58      0.54       100
#
# Accuracy 0.58
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 170, 0: 30})
#              precision    recall  f1-score   support
#
#           0       1.00      0.30      0.46       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.79      0.65      0.60       200
#
# Accuracy 0.65
# Counter({1: 75, 0: 25})
#              precision    recall  f1-score   support
#
#           0       0.72      0.36      0.48        50
#           1       0.57      0.86      0.69        50
#
# avg / total       0.65      0.61      0.58       100
#
# Accuracy 0.61
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 170, 0: 30})
#              precision    recall  f1-score   support
#
#           0       1.00      0.30      0.46       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.79      0.65      0.60       200
#
# Accuracy 0.65
# Counter({1: 72, 0: 28})
#              precision    recall  f1-score   support
#
#           0       0.75      0.42      0.54        50
#           1       0.60      0.86      0.70        50
#
# avg / total       0.67      0.64      0.62       100
#
# Accuracy 0.64
# __RUNNING ON pan14-author-verification-training-corpus-english-novels-2014-04-22/ pan14-author-verification-test-corpus2-english-novels-2014-04-22/
# Counter({1: 169, 0: 31})
#              precision    recall  f1-score   support
#
#           0       1.00      0.31      0.47       100
#           1       0.59      1.00      0.74       100
#
# avg / total       0.80      0.66      0.61       200
#
# Accuracy 0.655
# Counter({1: 65, 0: 35})
#              precision    recall  f1-score   support
#
#           0       0.80      0.56      0.66        50
#           1       0.66      0.86      0.75        50
#
# avg / total       0.73      0.71      0.70       100
#
# Accuracy 0.71
# test: [0.60113960113960108, 0.51553575166721499, 0.60113960113960108, 0.57889879149721679, 0.60838843326995662, 0.60113960113960108, 0.58639705882352944, 0.60113960113960108, 0.60113960113960108, 0.60838843326995662]
# test avg: 0.590330647422588
# train: [0.67676767676767668, 0.71440228478172174, 0.70763181772356087, 0.60933375567521908, 0.68077437956956022, 0.61240310077519378, 0.54427083333333337, 0.58399999999999996, 0.62168978562421184, 0.70332480818414322]
# train avg: 0.645459844243462
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 134, 0: 31})
#              precision    recall  f1-score   support
#
#           0       0.52      0.20      0.28        82
#           1       0.51      0.82      0.63        83
#
# avg / total       0.51      0.51      0.46       165
#
# Accuracy 0.509090909090909
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# Accuracy 0.52
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 140, 0: 25})
#              precision    recall  f1-score   support
#
#           0       0.52      0.16      0.24        82
#           1       0.51      0.86      0.64        83
#
# avg / total       0.51      0.51      0.44       165
#
# Accuracy 0.509090909090909
# Counter({1: 87, 0: 13})
#              precision    recall  f1-score   support
#
#           0       0.69      0.18      0.29        50
#           1       0.53      0.92      0.67        50
#
# avg / total       0.61      0.55      0.48       100
#
# Accuracy 0.55
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 116, 0: 49})
#              precision    recall  f1-score   support
#
#           0       0.47      0.28      0.35        82
#           1       0.49      0.69      0.57        83
#
# avg / total       0.48      0.48      0.46       165
#
# Accuracy 0.48484848484848486
# Counter({1: 71, 0: 29})
#              precision    recall  f1-score   support
#
#           0       0.52      0.30      0.38        50
#           1       0.51      0.72      0.60        50
#
# avg / total       0.51      0.51      0.49       100
#
# Accuracy 0.51
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 132, 0: 33})
#              precision    recall  f1-score   support
#
#           0       0.52      0.21      0.30        82
#           1       0.51      0.81      0.62        83
#
# avg / total       0.51      0.51      0.46       165
#
# Accuracy 0.509090909090909
# Counter({1: 89, 0: 11})
#              precision    recall  f1-score   support
#
#           0       0.55      0.12      0.20        50
#           1       0.51      0.90      0.65        50
#
# avg / total       0.53      0.51      0.42       100
#
# Accuracy 0.51
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 130, 0: 35})
#              precision    recall  f1-score   support
#
#           0       0.49      0.21      0.29        82
#           1       0.50      0.78      0.61        83
#
# avg / total       0.49      0.50      0.45       165
#
# Accuracy 0.49696969696969695
# Counter({1: 91, 0: 9})
#              precision    recall  f1-score   support
#
#           0       0.67      0.12      0.20        50
#           1       0.52      0.94      0.67        50
#
# avg / total       0.59      0.53      0.44       100
#
# Accuracy 0.53
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 100, 0: 65})
#              precision    recall  f1-score   support
#
#           0       0.49      0.39      0.44        82
#           1       0.50      0.60      0.55        83
#
# avg / total       0.50      0.50      0.49       165
#
# Accuracy 0.49696969696969695
# Counter({1: 71, 0: 29})
#              precision    recall  f1-score   support
#
#           0       0.66      0.38      0.48        50
#           1       0.56      0.80      0.66        50
#
# avg / total       0.61      0.59      0.57       100
#
# Accuracy 0.59
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 120, 0: 45})
#              precision    recall  f1-score   support
#
#           0       0.51      0.28      0.36        82
#           1       0.51      0.73      0.60        83
#
# avg / total       0.51      0.51      0.48       165
#
# Accuracy 0.509090909090909
# Counter({1: 88, 0: 12})
#              precision    recall  f1-score   support
#
#           0       0.75      0.18      0.29        50
#           1       0.53      0.94      0.68        50
#
# avg / total       0.64      0.56      0.49       100
#
# Accuracy 0.56
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 150, 0: 15})
#              precision    recall  f1-score   support
#
#           0       0.33      0.06      0.10        82
#           1       0.49      0.88      0.63        83
#
# avg / total       0.41      0.47      0.37       165
#
# Accuracy 0.4727272727272727
# Counter({1: 77, 0: 23})
#              precision    recall  f1-score   support
#
#           0       0.61      0.28      0.38        50
#           1       0.53      0.82      0.65        50
#
# avg / total       0.57      0.55      0.51       100
#
# Accuracy 0.55
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# Counter({1: 113, 0: 52})
#              precision    recall  f1-score   support
#
#           0       0.52      0.33      0.40        82
#           1       0.51      0.70      0.59        83
#
# avg / total       0.52      0.52      0.50       165
#
# Accuracy 0.5151515151515151
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# __RUNNING ON pan15-authorship-verification-training-dataset-dutch-2015-04-19/ pan15-authorship-verification-test-dataset2-dutch-2015-04-19/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 149, 0: 16})
#              precision    recall  f1-score   support
#
#           0       0.56      0.11      0.18        82
#           1       0.51      0.92      0.66        83
#
# avg / total       0.54      0.52      0.42       165
#
# Accuracy 0.5151515151515151
# Counter({1: 78, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.68      0.30      0.42        50
#           1       0.55      0.86      0.67        50
#
# avg / total       0.62      0.58      0.54       100
#
# Accuracy 0.58
# test: [0.45495697565352144, 0.43988097732701897, 0.46200467988798954, 0.45945399393326591, 0.45046346454797159, 0.49091111854577901, 0.48159497304216281, 0.36485111278262022, 0.49741090466037163, 0.41942294159042925]
# test avg: 0.452095114197113
# train: [0.37629937629937638, 0.47862356621480717, 0.4873940788785438, 0.42210166293194951, 0.43502824858757067, 0.57108484151061834, 0.48574100046750812, 0.51461546758709953, 0.33333333333333331, 0.54427083333333337]
# train avg: 0.46484924091441404
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       0.67      0.04      0.08        50
#           1       0.51      0.98      0.67        50
#
# avg / total       0.59      0.51      0.37       100
#
# Accuracy 0.51
# Counter({1: 73, 0: 27})
#              precision    recall  f1-score   support
#
#           0       0.63      0.34      0.44        50
#           1       0.55      0.80      0.65        50
#
# avg / total       0.59      0.57      0.55       100
#
# Accuracy 0.57
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 90, 0: 10})
#              precision    recall  f1-score   support
#
#           0       0.70      0.14      0.23        50
#           1       0.52      0.94      0.67        50
#
# avg / total       0.61      0.54      0.45       100
#
# Accuracy 0.54
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       0.67      0.04      0.08        50
#           1       0.51      0.98      0.67        50
#
# avg / total       0.59      0.51      0.37       100
#
# Accuracy 0.51
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       0.40      0.04      0.07        50
#           1       0.49      0.94      0.65        50
#
# avg / total       0.45      0.49      0.36       100
#
# Accuracy 0.49
# Counter({1: 78, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.55      0.24      0.33        50
#           1       0.51      0.80      0.62        50
#
# avg / total       0.53      0.52      0.48       100
#
# Accuracy 0.52
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 87, 0: 13})
#              precision    recall  f1-score   support
#
#           0       0.38      0.10      0.16        50
#           1       0.48      0.84      0.61        50
#
# avg / total       0.43      0.47      0.39       100
#
# Accuracy 0.47
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 73, 0: 27})
#              precision    recall  f1-score   support
#
#           0       0.63      0.34      0.44        50
#           1       0.55      0.80      0.65        50
#
# avg / total       0.59      0.57      0.55       100
#
# Accuracy 0.57
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 66, 0: 34})
#              precision    recall  f1-score   support
#
#           0       0.53      0.36      0.43        50
#           1       0.52      0.68      0.59        50
#
# avg / total       0.52      0.52      0.51       100
#
# Accuracy 0.52
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 78, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.59      0.26      0.36        50
#           1       0.53      0.82      0.64        50
#
# avg / total       0.56      0.54      0.50       100
#
# Accuracy 0.54
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 66, 0: 34})
#              precision    recall  f1-score   support
#
#           0       0.59      0.40      0.48        50
#           1       0.55      0.72      0.62        50
#
# avg / total       0.57      0.56      0.55       100
#
# Accuracy 0.56
# __RUNNING ON pan15-authorship-verification-training-dataset-greek-2015-04-19/ pan15-authorship-verification-test-dataset2-greek-2015-04-19/
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       0.50      0.02      0.04        50
#           1       0.50      0.98      0.66        50
#
# avg / total       0.50      0.50      0.35       100
#
# Accuracy 0.5
# Counter({1: 82, 0: 18})
#              precision    recall  f1-score   support
#
#           0       0.56      0.20      0.29        50
#           1       0.51      0.84      0.64        50
#
# avg / total       0.53      0.52      0.47       100
#
# Accuracy 0.52
# test: [0.37106918238993708, 0.33333333333333331, 0.35517831293591262, 0.36050156739811912, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.35517831293591262, 0.35517831293591262, 0.3503118503118503]
# test avg: 0.34807508722409775
# train: [0.54598247281174106, 0.45238095238095244, 0.37106918238993708, 0.47916666666666663, 0.38593442243077281, 0.54598247281174106, 0.50738916256157629, 0.50086805555555558, 0.54844006568144499, 0.46524064171123003]
# train avg: 0.4802454095001618
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 87, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.26      0.41        50
#           1       0.57      1.00      0.73        50
#
# avg / total       0.79      0.63      0.57       100
#
# Accuracy 0.63
# Counter({1: 70, 0: 30})
#              precision    recall  f1-score   support
#
#           0       0.63      0.38      0.48        50
#           1       0.56      0.78      0.65        50
#
# avg / total       0.60      0.58      0.56       100
#
# Accuracy 0.58
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 87, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.26      0.41        50
#           1       0.57      1.00      0.73        50
#
# avg / total       0.79      0.63      0.57       100
#
# Accuracy 0.63
# Counter({0: 55, 1: 45})
#              precision    recall  f1-score   support
#
#           0       0.60      0.66      0.63        50
#           1       0.62      0.56      0.59        50
#
# avg / total       0.61      0.61      0.61       100
#
# Accuracy 0.61
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 90, 0: 10})
#              precision    recall  f1-score   support
#
#           0       1.00      0.20      0.33        50
#           1       0.56      1.00      0.71        50
#
# avg / total       0.78      0.60      0.52       100
#
# Accuracy 0.6
# Counter({1: 62, 0: 38})
#              precision    recall  f1-score   support
#
#           0       0.76      0.58      0.66        50
#           1       0.66      0.82      0.73        50
#
# avg / total       0.71      0.70      0.70       100
#
# Accuracy 0.7
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 92, 0: 8})
#              precision    recall  f1-score   support
#
#           0       1.00      0.16      0.28        50
#           1       0.54      1.00      0.70        50
#
# avg / total       0.77      0.58      0.49       100
#
# Accuracy 0.58
# Counter({1: 64, 0: 36})
#              precision    recall  f1-score   support
#
#           0       0.61      0.44      0.51        50
#           1       0.56      0.72      0.63        50
#
# avg / total       0.59      0.58      0.57       100
#
# Accuracy 0.58
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 91, 0: 9})
#              precision    recall  f1-score   support
#
#           0       1.00      0.18      0.31        50
#           1       0.55      1.00      0.71        50
#
# avg / total       0.77      0.59      0.51       100
#
# Accuracy 0.59
# Counter({1: 61, 0: 39})
#              precision    recall  f1-score   support
#
#           0       0.67      0.52      0.58        50
#           1       0.61      0.74      0.67        50
#
# avg / total       0.64      0.63      0.63       100
#
# Accuracy 0.63
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 87, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.26      0.41        50
#           1       0.57      1.00      0.73        50
#
# avg / total       0.79      0.63      0.57       100
#
# Accuracy 0.63
# Counter({1: 61, 0: 39})
#              precision    recall  f1-score   support
#
#           0       0.54      0.42      0.47        50
#           1       0.52      0.64      0.58        50
#
# avg / total       0.53      0.53      0.52       100
#
# Accuracy 0.53
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 91, 0: 9})
#              precision    recall  f1-score   support
#
#           0       1.00      0.18      0.31        50
#           1       0.55      1.00      0.71        50
#
# avg / total       0.77      0.59      0.51       100
#
# Accuracy 0.59
# Counter({1: 70, 0: 30})
#              precision    recall  f1-score   support
#
#           0       0.77      0.46      0.57        50
#           1       0.61      0.86      0.72        50
#
# avg / total       0.69      0.66      0.65       100
#
# Accuracy 0.66
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 83, 0: 17})
#              precision    recall  f1-score   support
#
#           0       1.00      0.34      0.51        50
#           1       0.60      1.00      0.75        50
#
# avg / total       0.80      0.67      0.63       100
#
# Accuracy 0.67
# Counter({1: 91, 0: 9})
#              precision    recall  f1-score   support
#
#           0       1.00      0.18      0.31        50
#           1       0.55      1.00      0.71        50
#
# avg / total       0.77      0.59      0.51       100
#
# Accuracy 0.59
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 82, 0: 18})
#              precision    recall  f1-score   support
#
#           0       1.00      0.36      0.53        50
#           1       0.61      1.00      0.76        50
#
# avg / total       0.80      0.68      0.64       100
#
# Accuracy 0.68
# Counter({1: 57, 0: 43})
#              precision    recall  f1-score   support
#
#           0       0.63      0.54      0.58        50
#           1       0.60      0.68      0.64        50
#
# avg / total       0.61      0.61      0.61       100
#
# Accuracy 0.61
# __RUNNING ON pan15-authorship-verification-training-dataset-spanish-2015-04-19/ pan15-authorship-verification-test-dataset2-spanish-2015-04-19/
# Counter({1: 84, 0: 16})
#              precision    recall  f1-score   support
#
#           0       1.00      0.32      0.48        50
#           1       0.60      1.00      0.75        50
#
# avg / total       0.80      0.66      0.62       100
#
# Accuracy 0.66
# Counter({1: 62, 0: 38})
#              precision    recall  f1-score   support
#
#           0       0.58      0.44      0.50        50
#           1       0.55      0.68      0.61        50
#
# avg / total       0.56      0.56      0.55       100
#
# Accuracy 0.56
# test: [0.57131270999884143, 0.57131270999884143, 0.52380952380952384, 0.49004371053909668, 0.50715230195937011, 0.57131270999884143, 0.50715230195937011, 0.62967119290764229, 0.64349376114081991, 0.61555857078245135]
# test avg: 0.5630819493094799
# train: [0.5625, 0.60902255639097747, 0.69561688311688319, 0.57160342717258261, 0.62546816479400746, 0.52424334446806353, 0.64583333333333337, 0.50715230195937011, 0.60807958999095568, 0.5535714285714286]
# train avg: 0.5903091029797602
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 94, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        48
#           1       0.51      1.00      0.68        48
#
# avg / total       0.76      0.52      0.38        96
#
# Accuracy 0.5208333333333334
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# Accuracy 0.52
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       1.00      0.06      0.11        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.53      0.40       100
#
# Accuracy 0.53
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 95, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        48
#           1       0.51      1.00      0.67        48
#
# avg / total       0.75      0.51      0.36        96
#
# Accuracy 0.5104166666666666
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# Accuracy 0.52
# Counter({1: 96})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        48
#           1       0.50      1.00      0.67        48
#
# avg / total       0.25      0.50      0.33        96
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-reviews-2014-04-22/
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 94, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        48
#           1       0.51      1.00      0.68        48
#
# avg / total       0.76      0.52      0.38        96
#
# Accuracy 0.5208333333333334
# test: [0.35517831293591262, 0.37629937629937638, 0.39673982800667434, 0.35517831293591262, 0.35517831293591262, 0.35517831293591262, 0.35517831293591262, 0.33333333333333331, 0.37629937629937638, 0.33333333333333331]
# test avg: 0.3591896811951657
# train: [0.37802816901408448, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.35607249892964182, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.37802816901408448]
# train avg: 0.3445462170291144
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 83, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.27      0.43        48
#           1       0.58      1.00      0.73        48
#
# avg / total       0.79      0.64      0.58        96
#
# Accuracy 0.6354166666666666
# Counter({1: 78, 0: 18})
#              precision    recall  f1-score   support
#
#           0       0.94      0.35      0.52        48
#           1       0.60      0.98      0.75        48
#
# avg / total       0.77      0.67      0.63        96
#
# Accuracy 0.6666666666666666
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 84, 0: 12})
#              precision    recall  f1-score   support
#
#           0       1.00      0.25      0.40        48
#           1       0.57      1.00      0.73        48
#
# avg / total       0.79      0.62      0.56        96
#
# Accuracy 0.625
# Counter({1: 75, 0: 21})
#              precision    recall  f1-score   support
#
#           0       1.00      0.44      0.61        48
#           1       0.64      1.00      0.78        48
#
# avg / total       0.82      0.72      0.69        96
#
# Accuracy 0.71875
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 77, 0: 19})
#              precision    recall  f1-score   support
#
#           0       1.00      0.40      0.57        48
#           1       0.62      1.00      0.77        48
#
# avg / total       0.81      0.70      0.67        96
#
# Accuracy 0.6979166666666666
# Counter({1: 85, 0: 11})
#              precision    recall  f1-score   support
#
#           0       0.91      0.21      0.34        48
#           1       0.55      0.98      0.71        48
#
# avg / total       0.73      0.59      0.52        96
#
# Accuracy 0.59375
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 87, 0: 9})
#              precision    recall  f1-score   support
#
#           0       1.00      0.19      0.32        48
#           1       0.55      1.00      0.71        48
#
# avg / total       0.78      0.59      0.51        96
#
# Accuracy 0.59375
# Counter({1: 75, 0: 21})
#              precision    recall  f1-score   support
#
#           0       0.90      0.40      0.55        48
#           1       0.61      0.96      0.75        48
#
# avg / total       0.76      0.68      0.65        96
#
# Accuracy 0.6770833333333334
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 75, 0: 21})
#              precision    recall  f1-score   support
#
#           0       1.00      0.44      0.61        48
#           1       0.64      1.00      0.78        48
#
# avg / total       0.82      0.72      0.69        96
#
# Accuracy 0.71875
# Counter({1: 76, 0: 20})
#              precision    recall  f1-score   support
#
#           0       0.95      0.40      0.56        48
#           1       0.62      0.98      0.76        48
#
# avg / total       0.78      0.69      0.66        96
#
# Accuracy 0.6875
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 83, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.27      0.43        48
#           1       0.58      1.00      0.73        48
#
# avg / total       0.79      0.64      0.58        96
#
# Accuracy 0.6354166666666666
# Counter({1: 63, 0: 33})
#              precision    recall  f1-score   support
#
#           0       0.91      0.62      0.74        48
#           1       0.71      0.94      0.81        48
#
# avg / total       0.81      0.78      0.78        96
#
# Accuracy 0.78125
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 83, 0: 13})
#              precision    recall  f1-score   support
#
#           0       1.00      0.27      0.43        48
#           1       0.58      1.00      0.73        48
#
# avg / total       0.79      0.64      0.58        96
#
# Accuracy 0.6354166666666666
# Counter({1: 72, 0: 24})
#              precision    recall  f1-score   support
#
#           0       0.92      0.46      0.61        48
#           1       0.64      0.96      0.77        48
#
# avg / total       0.78      0.71      0.69        96
#
# Accuracy 0.7083333333333334
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 88, 0: 8})
#              precision    recall  f1-score   support
#
#           0       1.00      0.17      0.29        48
#           1       0.55      1.00      0.71        48
#
# avg / total       0.77      0.58      0.50        96
#
# Accuracy 0.5833333333333334
# Counter({1: 74, 0: 22})
#              precision    recall  f1-score   support
#
#           0       0.95      0.44      0.60        48
#           1       0.64      0.98      0.77        48
#
# avg / total       0.79      0.71      0.69        96
#
# Accuracy 0.7083333333333334
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 77, 0: 19})
#              precision    recall  f1-score   support
#
#           0       0.89      0.35      0.51        48
#           1       0.60      0.96      0.74        48
#
# avg / total       0.75      0.66      0.62        96
#
# Accuracy 0.65625
# Counter({1: 79, 0: 17})
#              precision    recall  f1-score   support
#
#           0       0.94      0.33      0.49        48
#           1       0.59      0.98      0.74        48
#
# avg / total       0.77      0.66      0.62        96
#
# Accuracy 0.65625
# __RUNNING ON pan14-author-verification-training-corpus-dutch-essays-2014-04-22/ pan14-author-verification-test-corpus2-dutch-essays-2014-04-22/
# Counter({1: 79, 0: 17})
#              precision    recall  f1-score   support
#
#           0       0.94      0.33      0.49        48
#           1       0.59      0.98      0.74        48
#
# avg / total       0.77      0.66      0.62        96
#
# Accuracy 0.65625
# Counter({1: 77, 0: 19})
#              precision    recall  f1-score   support
#
#           0       0.95      0.38      0.54        48
#           1       0.61      0.98      0.75        48
#
# avg / total       0.78      0.68      0.64        96
#
# Accuracy 0.6770833333333334
# test: [0.57952696783881863, 0.56363636363636371, 0.66758208955223886, 0.51345029239766082, 0.69459172852598083, 0.57952696783881863, 0.57952696783881863, 0.49579831932773105, 0.62173134328358204, 0.61623258631132649]
# test avg: 0.5911603626551339
# train: [0.63059163059163059, 0.69459172852598083, 0.52287498407034527, 0.64934605867797801, 0.65844402277039848, 0.77577577577577572, 0.68888888888888888, 0.68524590163934418, 0.61623258631132649, 0.64465671641791045]
# train avg: 0.6566648293669579
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/

# %%
for train, test in dataset_pairs[-2:]:
    run_experiment_n_times(train, test, 10)
# Out:
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 94, 0: 6})
#              precision    recall  f1-score   support
#
#           0       1.00      0.12      0.21        50
#           1       0.53      1.00      0.69        50
#
# avg / total       0.77      0.56      0.45       100
#
# Accuracy 0.56
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       1.00      0.10      0.18        50
#           1       0.53      1.00      0.69        50
#
# avg / total       0.76      0.55      0.44       100
#
# Accuracy 0.55
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 88, 0: 12})
#              precision    recall  f1-score   support
#
#           0       0.75      0.18      0.29        50
#           1       0.53      0.94      0.68        50
#
# avg / total       0.64      0.56      0.49       100
#
# Accuracy 0.56
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       1.00      0.06      0.11        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.53      0.40       100
#
# Accuracy 0.53
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 94, 0: 6})
#              precision    recall  f1-score   support
#
#           0       0.67      0.08      0.14        50
#           1       0.51      0.96      0.67        50
#
# avg / total       0.59      0.52      0.40       100
#
# Accuracy 0.52
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 96, 0: 4})
#              precision    recall  f1-score   support
#
#           0       1.00      0.08      0.15        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.54      0.42       100
#
# Accuracy 0.54
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       1.00      0.02      0.04        50
#           1       0.51      1.00      0.67        50
#
# avg / total       0.75      0.51      0.36       100
#
# Accuracy 0.51
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 99, 0: 1})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.49      0.98      0.66        50
#
# avg / total       0.25      0.49      0.33       100
#
# Accuracy 0.49
# __RUNNING ON pan14-author-verification-training-corpus-greek-articles-2014-04-22/ pan14-author-verification-test-corpus2-greek-articles-2014-04-22/
# Counter({1: 100})
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        50
#           1       0.50      1.00      0.67        50
#
# avg / total       0.25      0.50      0.33       100
#
# Accuracy 0.5
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# Accuracy 0.52
# test: [0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331, 0.33333333333333331]
# test avg: 0.3333333333333333
# train: [0.45436507936507931, 0.43573667711598751, 0.48574100046750812, 0.39673982800667434, 0.40476190476190477, 0.41653982749873159, 0.35517831293591262, 0.33333333333333331, 0.32885906040268453, 0.37629937629937638]
# train avg: 0.39875544001871926
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 98, 0: 2})
#              precision    recall  f1-score   support
#
#           0       1.00      0.04      0.08        50
#           1       0.51      1.00      0.68        50
#
# avg / total       0.76      0.52      0.38       100
#
# Accuracy 0.52
# Counter({1: 82, 0: 18})
#              precision    recall  f1-score   support
#
#           0       0.61      0.22      0.32        50
#           1       0.52      0.86      0.65        50
#
# avg / total       0.57      0.54      0.49       100
#
# Accuracy 0.54
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       0.80      0.08      0.15        50
#           1       0.52      0.98      0.68        50
#
# avg / total       0.66      0.53      0.41       100
#
# Accuracy 0.53
# Counter({1: 90, 0: 10})
#              precision    recall  f1-score   support
#
#           0       0.80      0.16      0.27        50
#           1       0.53      0.96      0.69        50
#
# avg / total       0.67      0.56      0.48       100
#
# Accuracy 0.56
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       1.00      0.10      0.18        50
#           1       0.53      1.00      0.69        50
#
# avg / total       0.76      0.55      0.44       100
#
# Accuracy 0.55
# Counter({1: 89, 0: 11})
#              precision    recall  f1-score   support
#
#           0       0.55      0.12      0.20        50
#           1       0.51      0.90      0.65        50
#
# avg / total       0.53      0.51      0.42       100
#
# Accuracy 0.51
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 96, 0: 4})
#              precision    recall  f1-score   support
#
#           0       1.00      0.08      0.15        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.54      0.42       100
#
# Accuracy 0.54
# Counter({1: 82, 0: 18})
#              precision    recall  f1-score   support
#
#           0       0.56      0.20      0.29        50
#           1       0.51      0.84      0.64        50
#
# avg / total       0.53      0.52      0.47       100
#
# Accuracy 0.52
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       0.67      0.04      0.08        50
#           1       0.51      0.98      0.67        50
#
# avg / total       0.59      0.51      0.37       100
#
# Accuracy 0.51
# Counter({1: 83, 0: 17})
#              precision    recall  f1-score   support
#
#           0       0.53      0.18      0.27        50
#           1       0.51      0.84      0.63        50
#
# avg / total       0.52      0.51      0.45       100
#
# Accuracy 0.51
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       0.80      0.08      0.15        50
#           1       0.52      0.98      0.68        50
#
# avg / total       0.66      0.53      0.41       100
#
# Accuracy 0.53
# Counter({1: 96, 0: 4})
#              precision    recall  f1-score   support
#
#           0       1.00      0.08      0.15        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.54      0.42       100
#
# Accuracy 0.54
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 94, 0: 6})
#              precision    recall  f1-score   support
#
#           0       0.83      0.10      0.18        50
#           1       0.52      0.98      0.68        50
#
# avg / total       0.68      0.54      0.43       100
#
# Accuracy 0.54
# Counter({1: 90, 0: 10})
#              precision    recall  f1-score   support
#
#           0       0.70      0.14      0.23        50
#           1       0.52      0.94      0.67        50
#
# avg / total       0.61      0.54      0.45       100
#
# Accuracy 0.54
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 94, 0: 6})
#              precision    recall  f1-score   support
#
#           0       0.67      0.08      0.14        50
#           1       0.51      0.96      0.67        50
#
# avg / total       0.59      0.52      0.40       100
#
# Accuracy 0.52
# Counter({1: 80, 0: 20})
#              precision    recall  f1-score   support
#
#           0       0.60      0.24      0.34        50
#           1       0.53      0.84      0.65        50
#
# avg / total       0.56      0.54      0.49       100
#
# Accuracy 0.54
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 97, 0: 3})
#              precision    recall  f1-score   support
#
#           0       1.00      0.06      0.11        50
#           1       0.52      1.00      0.68        50
#
# avg / total       0.76      0.53      0.40       100
#
# Accuracy 0.53
# Counter({1: 81, 0: 19})
#              precision    recall  f1-score   support
#
#           0       0.53      0.20      0.29        50
#           1       0.51      0.82      0.63        50
#
# avg / total       0.52      0.51      0.46       100
#
# Accuracy 0.51
# __RUNNING ON pan14-author-verification-training-corpus-spanish-articles-2014-04-22/ pan14-author-verification-test-corpus2-spanish-articles-2014-04-22/
# Counter({1: 95, 0: 5})
#              precision    recall  f1-score   support
#
#           0       0.80      0.08      0.15        50
#           1       0.52      0.98      0.68        50
#
# avg / total       0.66      0.53      0.41       100
#
# Accuracy 0.53
# Counter({1: 84, 0: 16})
#              precision    recall  f1-score   support
#
#           0       0.62      0.20      0.30        50
#           1       0.52      0.88      0.66        50
#
# avg / total       0.57      0.54      0.48       100
#
# Accuracy 0.54
# test: [0.37629937629937638, 0.41065830721003138, 0.43573667711598751, 0.41653982749873159, 0.37106918238993708, 0.41065830721003138, 0.42956349206349209, 0.40476190476190477, 0.39673982800667434, 0.41065830721003138]
# test avg: 0.4062685209766198
# train: [0.48752228163992872, 0.47619047619047628, 0.42210166293194951, 0.46524064171123003, 0.45011783189316573, 0.41653982749873159, 0.45238095238095244, 0.49450549450549453, 0.45790463546852528, 0.47987336047037543]
# train avg: 0.46023771646908296
