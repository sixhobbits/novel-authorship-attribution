# %% [markdown]
# # Sandbox for PAN experiments
#
# ### To do
# * ~~Pan 14 and 16 (?) have HTML tags in the text tweets~~ BeautifulSoup is slow
# * Pan 14 and 16 have duplicates (between and among?)
# * Langauge data

# %%
import os

data_dir = "/data/pan17"

# 2014 training twitter
en14 = "pan14-author-profiling-training-dataset-english-twitter-2014-04-16"
es14 = "pan14-author-profiling-training-dataset-spanish-twitter-2014-04-16"
pan14 = [os.path.join(data_dir, d) for d in [en14, es14]]

# 2015 training (all twitter)
# below also have 2015-03-02 versions
du15 = "pan15-author-profiling-training-dataset-dutch-2015-04-23"
en15 = "pan15-author-profiling-training-dataset-english-2015-04-23"
it15 = "pan15-author-profiling-training-dataset-italian-2015-04-23"
es15 = "pan15-author-profiling-training-dataset-spanish-2015-04-23"
pan15 = [os.path.join(data_dir, d) for d in [du15, en15, it15, es15]]

# 2016 training (all twitter)
# below also have 2016-02-29 and 2-16-03-26 versions
du16 = "pan16-author-profiling-training-dataset-dutch-2016-04-25"
en16 = "pan16-author-profiling-training-dataset-english-2016-04-25"
es16 = "pan16-author-profiling-training-dataset-spanish-2016-04-25"
pan16 = [os.path.join(data_dir, d) for d in [du16, en16, es16]]

# 2017 training (all twitter)
pan17_root = "pan17-author-profiling-training-dataset-2017-03-10"
ar17 = os.path.join(pan17_root, "ar")
en17 = os.path.join(pan17_root, "en")
es17 = os.path.join(pan17_root, "es")
pt17 = os.path.join(pan17_root, "pt")
pan17 = [os.path.join(data_dir, d) for d in [ar17, en17, es17, pt17]]

# %%
import xmltodict
import logging
import glob
import os
import pandas as pd
import sys
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore", category=UserWarning)



# Main dataset loading utility
class PanDataLoader:
    
    def __init__(self, logger=None):
        if logger is None:
            logging.basicConfig(level=logging.DEBUG, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s")
            self.log = logging.getLogger(__name__)
        else:
            self.log = logger
                               
    def load_17(self, directory):
            
        """Load and return the pan17 gender and variation twitter dataset.
        ==============                                      ==============
        Samples total                                                10800
        Targets            nominal [{male, female},
                                    {ar, pt, es, en},
                                    {'brazil', 'australia', 'venezuela',
                                     'portugal', 'great britain', 'chile',
                                     'levantine', 'egypt', 'colombia',
                                     'peru', 'ireland', 'argentina',
                                     'maghrebi', 'mexico', 'new zealand',
                                     'spain', 'canada', 'gulf'}]
        ==============                                      ==============
        Parameters
        ----------
        inputdir
        The directory containing the training data, i.e. /data/training.

        Returns
        -------
        data : Pandas dataframe
            The interesting attributes are:
            'text', the data to learn, ['gender','lang', variety],
            the regression targets,
        Examples
        --------
        >>> from datasets import load_pan17
        >>> df_training = load_pan17(inputdir)
        >>> print(df_training.corpus.shape)
        (10800, 5)
        """

        X_docs = glob.glob(os.path.join(directory, '*.xml'), recursive=True)
        Y_doc = os.path.join(directory, 'truth.txt')
        # check that the dataset is loaded correctly

        X_tmp = []
        for t in X_docs:
            with open(t) as f:
                doc = xmltodict.parse(f.read())
            author = os.path.splitext(os.path.basename(t))[0]
            lang = doc['author']['@lang']
            text = doc['author']['documents']['document']
            X_tmp.append((author, lang, text))

        text = pd.DataFrame(X_tmp, columns=["author", "lang", "text"])

        Y_tmp = pd.read_csv(Y_doc,
                             sep='\:\:\:',
                             names=['author', 'gender', 'variety'],
                             engine='python')

        corpus = pd.merge(text, Y_tmp, on='author')
        return corpus
    
    def load_16(self, directory):
        return self.load_14(directory)
    
    def load_15(self, directory):
        X_docs = glob.glob(os.path.join(directory, '*.xml'), recursive=True)
        Y_doc = os.path.join(directory, 'truth.txt')
        X_tmp = []
        for t in X_docs:
            with open(t) as f:
                doc = xmltodict.parse(f.read())
            author = os.path.splitext(os.path.basename(t))[0]
            lang = doc['author']['@lang']
            text = doc['author']['document']
            # print(author, lang, text[:100])
            X_tmp.append((author, lang, text))

        text = pd.DataFrame(X_tmp, columns=["author", "lang", "text"])

        Y_tmp = pd.read_csv(Y_doc,
                             sep='\:\:\:',
                             names=['author', 'gender', 'age', '1','2','3','4', '5'],
                             engine='python') 


        corpus = pd.merge(text, Y_tmp, on='author')
        return corpus
    
    
    def load_14(self, directory):
        errors = 0
        X_docs = glob.glob(os.path.join(directory, '*.xml'), recursive=True)
        Y_doc = os.path.join(directory, 'truth.txt')
        X_tmp = []
        for t in X_docs:
            with open(t) as f:
                try:
                    doc = xmltodict.parse(f.read())
                except Exception as e:
                    self.log.warning(e)
                    self.log.warning("Skipping: {}".format(t))
                    continue
            author = os.path.splitext(os.path.basename(t))[0]
            lang = doc['author']['@lang']
            text = []
            for td in doc['author']['documents']['document']:
                try:
                    t = BeautifulSoup(td['#text'], "lxml").getText()
                    text.append(t)
                except Exception as e:
                    errors += 1
                    # log.warning(e)
                    # self.log.warning("skipping {}".format(td))
                    continue
            X_tmp.append((author, lang, text))

        text = pd.DataFrame(X_tmp, columns=["author", "lang", "text"])

        Y_tmp = pd.read_csv(Y_doc,
                             sep='\:\:\:',
                             names=['author', 'gender', 'age'],
                             engine='python') 

        self.log.warning("Skipped {}".format(errors))

        corpus = pd.merge(text, Y_tmp, on='author')
        return corpus
    
    def _load_all(self, loader_func, directories):
        """Concatenate across languages"""
        corpora = []
        for dr in directories:
            corpus = loader_func(dr)
            corpora.append(corpus)
        return pd.concat(corpora)
    
    def load_all_17(self, directories):
        return self._load_all(self.load_17, directories)
    
    def load_all_16(self, directories):
        return self._load_all(self.load_16, directories)
    
    def load_all_15(self, directories):
        return self._load_all(self.load_15, directories)
    
    def load_all_14(self, directories):
        return self._load_all(self.load_14, directories)
    
    def clean_and_normalize(self, corpus):
        """Standardize to lowercase for gender and langauge, m/f for gender
           Remove personality scores"""
        # FIXME TODO -- how do you do this in place?
        # FIXME TODO -- normalize age ranges?
        corpus['gender'] = corpus['gender'].apply(lambda s: s[0].lower())
        corpus['lang'] = corpus['lang'].apply(lambda s: s.lower())

        for c in ['1', '2', '3', '4', '5']:
            if c in corpus:
                del corpus[c]
        return corpus

# %%
pdl = PanDataLoader()

# %%
# corpus14 = pdl.load_all_14(pan14)
# corpus15 = pdl.load_all_15(pan15)
# 1189  fd90fd8495321f7f208c375fa7ddcce4   pt
# 1190  fdb495e343b266ad1fede476d8f31ab7   pt
# 1191  fdc0d8ec0db4fc5ca021c0a444f692c2   pt
# 1192  fdf14cb5e60e8632d83322b20062ead2   pt
# 1193  fdf50ec1511b598af4244d06e218cc18   pt
# 1194  fe40285d4dbb2d5872dcd7ff05c754a2   pt
# 1195  fe7d2f2887b742ebbe9a44c4dd93e4fc   pt
# 1196  feb75685b4844efd213e466511043319   pt
# 1197  fec130303839eef402373f86aba9175c   pt
# 1198  fedc3acdb6c0105bcf346efa9c537af4   pt
# 1199  ff0e7cfccdbe0a3256a95d0a143bf8e2   pt
#
#                                                    text  gender    variety
# 0     [#فخامه_العماد_المقاوم اللي ما بيتغيّر مش متل ...  female  levantine
# 1     [@faris_dody ربنا يخليه وتفرحي بيه 😘😘, كفاية ش...  female      egypt
# 2     [لسه ما لحقت افتح الفيسبوك صارت لاقطيتني يا ال...  female  levantine
# 3     [@Taher_NourEldin شاقط واحدة وبيتغدا معاها, أب...    male      egypt
# 4     [@Shereyn3 ده الانجليز اللي احتلونا هما كمان ب...  female      egypt
# 5     [...\n...\nنحبُّ الشّتاءَ، إذا انقطع الدَّربُ،...  female       gulf
# 6     [على سعيد الكعبى بيذيع ........متعة, @Egyleg 2...    male      egypt
# 7     [مساء الخير يا أوسخ جمهور في مصر إلا من رحم رب...    male      egypt
# 8     [في حدا بس يسويلي لايك برجع بقرأ شو كاتبة \n😂🙈...  female  levantine
# 9     [@allthings_D yas! المجموعة المصرية للعيون, @M...    male      egypt
# 10    [" لا تفتح باباً يُؤذيك، ولو كان الطارق شخصًا ...  female   maghrebi
# 11    [اللهم منزل الكتاب سريع الحساب اهزم الأحزاب ht...    male      egypt
# 12    [ملامح وجهِك كفيله بإنها تبدل عبُوس وجهي لفرح،...  female  levantine
# 13    [#لفها_بايدك https://t.co/jI0eLxUljg, @Sawalqa...    male  levantine
# 14    [الله يبارك فيك.يا حبيبي https://t.co/jdTNGnfq...    male      egypt
# 15    [@mohamed_ouni اللهم صل وسلم على نبينا محمد وع...  female   maghrebi
# 16    [اصبحنا واصبح الملك لله الواحد القهار \nصباح ا...    male  levantine
# 17    [@MAwamle كل المحبة والتقدير  ..نور بدرك يخطف ...    male  levantine
# 18    [لك أن تتخيل ماذا حدث\nمسخرة السنين :D :D :D h...    male      egypt
# 19    [كل حاجه هتبقي حلوه زي لون قلبك تمام❤❤, = أنا ...    male      egypt
# 20    [في ناس بين الناس غيمة مطر\nوفي ناس بين الناس ...    male  levantine
# 21    [(قل أرأيتم إن كان من عند الله ثم كفرتم به من ...  female      egypt
# 22    [@OMAR_AHMED_NOUH هيا فين نزل صورتها بقى😂😂😂, @...    male      egypt
# 23    [@MSH_koji اموتش عزيزتي, @MSH_koji التوقيت حال...  female       gulf
# 24    [اللهم صل وسلم على نبينا محمد\n♻️ https://t.co...    male      egypt
# 25    [اللهم إني ظلمت نفسي ظلماً كثيراً ولا يغفر الذ...  female       gulf
# 26    [@NabeelAliBinAli عليه السلام., @KSA24 #مسابقه...    male   maghrebi
# 27    [@miro_siam @mernamoharam1 @Rana__Samaha شكرا ...  female      egypt
# 28    [تطبيق مبدع وأنيق https://t.co/89IN99JCLB, @Mi...    male  levantine
# 29    [@balloutao الاشرفية روم 😂😂, @viktorjarjoura ا...    male  levantine
# ...                                                 ...     ...        ...
# 1170  [Mas foi de coração. Longe de mim falar mal de...  female     brazil
# 1171  [Eraldo soltou uma ótima na sala hoje, que cen...  female     brazil
# 1172  [@ricardo_kings se quiseres vem ai a minha cas...    male   portugal
# 1173  [A Ana é bue engraçada 😂 está na aula comigo e...    male   portugal
# 1174  [QUANDO EU ESTOU COM DOR DE CABEÇA PARECE QUE ...    male     brazil
# 1175  [jr nem m sinto mt cansado com este curso, o m...    male   portugal
# 1176  [Cheguei num estágio que não tenho mais corage...  female     brazil
# 1177  [O cartaz dos melhores do ano 2017 está topzão...    male   portugal
# 1178  ["Goxto de espermer brobulhas na aula de portu...    male   portugal
# 1179  [Você poderia pedir desculpas mudando suas ati...    male     brazil
# 1180  [Gostei de um vídeo @YouTube de @pyongleetv ht...    male     brazil
# 1181  [Já vai em 4 pontos roubados, nos últimos 3 jo...    male   portugal
# 1182  [Eu acredito sim, que um dia terei uma amiga q...  female     brazil
# 1183  [ele adormeceu, quase de certeza, algo me diz ...  female   portugal
# 1184  [Quero outro feriado essa semana. Vamos invent...  female     brazil
# 1185  [Falta pouco mais de uma hora pro niver da Joy...    male     brazil
# 1186  [Tem uns RNs que se iludem com qualquer especu...    male     brazil
# 1187  [Só queria uma massagem, tô precisando tanto, ...    male     brazil
# 1188  [Grande vitória das MICRO E PEQUENAS EMPRESAS ...    male     brazil
# 1189  [Focar no que realmente interessa, Sporting, S...    male   portugal
# 1190  [Não me fodas a semana benfica, @__Manada__ Em...    male   portugal
# 1191  [@andreiaa_moura @martapcastelo em termos de p...  female   portugal
# 1192  [As vezes esqueço ate de cuidar dos meus SIMS ...  female     brazil
# 1193  [@luisfilipe98 eu assistiria de novo se eu não...  female     brazil
# 1194  [Caminhada matutina neste domingo, 29 de janei...    male     brazil
# 1195  [E esse tanto de avião caindo EU HEIN, É aquel...  female     brazil
# 1196  [Deu-me uma impressão na barriga só de ver cre...  female   portugal
# 1197  [@axexeo tão querido você! Muito prazer te ver...  female     brazil
# 1198  [@psicth ficava mesmo ;), Vc tá cursando qual ...    male     brazil
# 1199  [Miminhos era bom agora, Nunca dou favs à toa,...  female   portugal
#
# [11400 rows x 5 columns]

# %%
# find duplicates
authors = [set(corpus['author']) for corpus in [corpus14, corpus15, corpus16, corpus17]]
duplicates = [[0 for _ in range(len(authors))] for __ in range(len(authors))]
for j in range(len(authors)):
    for k in range(len(authors)):
        duplicates[j][k] = str(len(authors[j].intersection(authors[k]))).zfill(3)

for line in duplicates:
    print(line)
# Out:
# ['425', '000', '397', '000']
# ['000', '324', '000', '000']
# ['397', '000', '594', '000']
# ['000', '000', '000', '11400']

# %%
# there are duplicates between 14 and 16

duplicates = set(corpus14['author']).intersection(set(corpus16['author']))
num_duplicates = len(duplicates)
print(num_duplicates)
print(len(corpus14['author']))
print(len(corpus16['author']))
# Out:
# 397
# 483
# 678

# %%
for c in [corpus14, corpus15, corpus16, corpus17]:
    n_authors = len(c['author'])
    u_authors = len(set(c['author']))
    print("{} {}: {}".format(n_authors, u_authors, n_authors - u_authors))
# Out:
# 483 425: 58
# 324 324: 0
# 678 594: 84
# 11400 11400: 0

# %%
# removes duplicates but doesn't regard language
corpus16[~corpus16['author'].isin(corpus14['author'])]
# Out:
#                                author lang  \
# 3    6e602536dfb72bb2c881fd25e6a92f46   EN
# 5    b9114397ca060ce9de73d8073b0c53c3   EN
# 6    43d7f732e9da60bc1d8f13294c3a3f1c   EN
# 8    e827776a1e77b7bee940b485c5a4b5b7   EN
# 14   b88171637fa04a302e94b14402f2793a   EN
# 16   ca75d60a9ff2c98b575535212f338b6a   EN
# 18   638475f75a7f842d4ce14e690012a5cf   EN
# 24   a882cbfa5477e22a082c5b0c0c288dfb   EN
# 25   f5abf96f244c876d17ecf69863cb0abb   EN
# 29   29498c0afa48a739013e2a3f8c1e2937   EN
# 31   6a37a45999b35bbdd1bcac74f1243be3   EN
# 33   7d907696792f2ffebe9eb6fc7448ee4f   EN
# 34   98d2fadb624ce637f63d00e46aca5fc7   EN
# 36   80d92cf1ea27e001428c05bed7de7aae   EN
# 38   2045de9e2f46e9dad1bd91c14aa85d0b   EN
# 40   4e3cbdeeccfe7c5dd61d0b3b73444d69   EN
# 47   20bf285bfb69897524b8c444a8ca197d   EN
# 62   25870981b463d9b45361330190d60f53   EN
# 65   780a57a7ecdb4ecbdcaf20e0435de9ff   EN
# 66   9fccd14981cc04ff92a399dbfee1a0b7   EN
# 70   88933cee52db6f5c0c0f04d05fcaf614   EN
# 72   146bcb261292b6ae2c3416fdc3ed5c81   EN
# 73   862463c413570ea28c694a9fa06a6599   EN
# 77   d098f4dc43d5c4768056c2dc8e1b5328   EN
# 82   e3a56670ae34a61476c1ebb5fab5fbd2   EN
# 89   c8991753dc81f5ec9bf1b8a7137aa6a2   EN
# 94   3373639b1d50d755c03c02cd9b93b720   EN
# 100  76b6283d82da63a42ae8a42e7da628ec   EN
# 101  078242a7701728828d6d98cd42f3f48e   EN
# 102  f677a164b16096fc2eb3af86694da8ac   EN
# ..                                ...  ...
# 182  32b65607f33f98b906aa95a4401537b5   ES
# 183  c337d43f6323473feaa311f04a0bbdb8   ES
# 186  1909f5636bd3c66a5040571a89e412f0   ES
# 188  dc686ee6d6a056949888a0ef95f0c077   ES
# 193  a6d5c1dc7657c9fd0bfb87bdc0376355   ES
# 195  60f601460f83a4adac3ee69528bea01c   ES
# 196  32ef23eb13f83e2ac48603e55867894f   ES
# 201  c7ad6c96208a6ecf83542130321074ad   ES
# 205  272f4ed6162858e967c761fd828f54a4   ES
# 211  b88da75a9d31ec81044e6cb1f58b2439   ES
# 212  8011a415094ba45779b68f90e98de663   ES
# 213  a85048d95bfe0834c8d20cf24aa7cc85   ES
# 215  d06041e62858324f580ea8b90473e294   ES
# 216  9ca1e5c0183be34fce6645caef9c6b05   ES
# 219  43fd2e9d7b3c55435a849de5c5c43f1b   ES
# 220  ba60ddef7a784f9d15793b264e107098   ES
# 222  a165f5ea81180a72ccf49761dbf8247d   ES
# 223  838b6023caf2198603ae46eb764a952e   ES
# 228  89f1dc1f58ef3f17bbeac06560046bde   ES
# 230  f18d7e12e5b5ea1ef326a3cb7ac93af0   ES
# 232  441ef647f0531cb4546d6d7353eca668   ES
# 233  7bf164306e70a528652a3289be2fde26   ES
# 234  1cddde52f7a410427df4975fd837906f   ES
# 235  fff6e87e99c0182e11ed7ab3fc4cfe05   ES
# 239  61a47f23198d8ebc0034fc0cbe802f02   ES
# 240  c89524bc2de8ad60c75f7fd91a154a29   ES
# 241  74ac94e14daccfdcb4370f2ee59cce90   ES
# 243  a10107f166b13214edc2fece85264a62   ES
# 245  e669e24fa419cfa4dc1eac97179183ff   ES
# 249  f0973636511e31a642a0bd88e8831bce   ES
#
#                                                   text  gender    age
# 3    [Attending <a href="/hashtag/gbl10?src=hash" d...    MALE  25-34
# 5    [Infographic: Doctors Prescribing More Mobile ...  FEMALE  35-49
# 6    [<a href="/s99drine" class="twitter-atreply pr...  FEMALE  35-49
# 8    [<a href="/hashtag/tweetameet?src=hash" data-q...    MALE  25-34
# 14   [<a href="/scottsanchez" class="twitter-atrepl...    MALE  25-34
# 16   [<a href="/alexismadrigal" class="twitter-atre...    MALE  35-49
# 18   [OUTSIDE THE STUDIO: Art in the Park w BVAG - ...  FEMALE  50-64
# 24   [Sebastian Ingrosso, Tommy Trash, John Martin ...  FEMALE  18-24
# 25   [@socialmurcia1 <a href="/smerigom" class="twi...  FEMALE  35-49
# 29   [Gracias por seguirme: <a href="/AppleMacWatch...    MALE  35-49
# 31   [<a href="/thatkristen" class="twitter-atreply...  FEMALE  35-49
# 33   [Dr. Appt (@ St. Thomas Neurology)<a href="htt...  FEMALE  25-34
# 34   [Photographic Challenge: Toys - <a href="/hash...  FEMALE  25-34
# 36   [Rosa Baez (with English subtitles) <a href="h...    MALE  50-64
# 38   [Poll on what compression is usual after micro...    MALE  35-49
# 40   [The linen is over but now we have gold :-), <...    MALE  25-34
# 47   [Check out my professional profile and connect...    MALE  25-34
# 62   [<a href="/yndytv" class="twitter-atreply pret...    MALE  25-34
# 65   [The Mountaintop starts previews tonight at th...  FEMALE  35-49
# 66   [Coming to Nyack and NYC next week. Just a few...  FEMALE  35-49
# 70   [<a href="/BobMiller146" class="twitter-atrepl...    MALE  50-64
# 72   [Businessweek: &quot;Camera, phone, music... T...    MALE  18-24
# 73   [I&#39;m at Centro CRECE<a href="http://t.co/O...    MALE  25-34
# 77   [<a href="/dexdexxx5" class="twitter-atreply p...    MALE  50-64
# 82   [Cenando con <a href="/frank_vasques" class="t...    MALE  18-24
# 89   [Innovation Isn’t ‘Creativity,’ It’s a Discipl...    MALE  35-49
# 94   [One lonely liberal chanting &quot;SHUT DOWN M...    MALE  35-49
# 100  [<a href="/cvharquail" class="twitter-atreply ...  FEMALE  35-49
# 101  [Just posted a photo <a href="http://t.co/ciYu...  FEMALE  35-49
# 102  [Flashback: WSJ (7/28/11): The Road to a Downg...    MALE  25-34
# ..                                                 ...     ...    ...
# 182  [:) <a href="/farmaem" class="twitter-atreply ...    MALE  50-64
# 183  [<a href="/FedericoQuevedo" class="twitter-atr...    MALE  50-64
# 186  [<a href="/KissPink1983" class="twitter-atrepl...  FEMALE  35-49
# 188  [Turismo, un sector en temporada alta. <a href...    MALE  65-xx
# 193  [<a href="/R_Loren" class="twitter-atreply pre...  FEMALE  25-34
# 195  [A Punto de tener la primera entrevista del di...  FEMALE  35-49
# 196  [Estamos en Laos renovando visado Y contentos ...    MALE  25-34
# 201  [Rt “<a href="/david_carnicer" class="twitter-...    MALE  35-49
# 205  [Cuanto odio chica <a href="/PiLUKA10" class="...  FEMALE  35-49
# 211  [I uploaded a YouTube video -- Careta http://y...  FEMALE  25-34
# 212  [<a href="/patriciosanchz" class="twitter-atre...  FEMALE  35-49
# 213  [Dos varas de medir: Alemania antes, Grecia ah...    MALE  50-64
# 215  [Artículo de O Globo: &quot;Atuação de diploma...    MALE  35-49
# 216  [Experiencias nuevas, como saltar al vacío &qu...    MALE  50-64
# 219  [&quot;España hoy según los corresponsales ext...  FEMALE  35-49
# 220  [Me han llegado las fechas para organizar unas...  FEMALE  35-49
# 222  [<a href="/checomg91" class="twitter-atreply p...    MALE  35-49
# 223  [“<a href="/JavierPeris" class="twitter-atrepl...    MALE  35-49
# 228  [Cómo difundir tu propuesta solidaria en las r...  FEMALE  25-34
# 230  [<a href="/Mixalberto" class="twitter-atreply ...    MALE  35-49
# 232  [Gracias a todos x los <a href="/hashtag/GRACI...  FEMALE  18-24
# 233  [El Banco Central Europeo no es un banco centr...    MALE  35-49
# 234  [Empieza a hacer frío en casa a esta hora. 11º...  FEMALE  35-49
# 235  [CERTIFICADOS MÉDICOS NO ES AQUÍ!!! Que es lo ...    MALE  25-34
# 239  [<a href="/A_BelenEsteban" class="twitter-atre...  FEMALE  50-64
# 240                                                 []    MALE  25-34
# 241  [<a href="/rochgs" class="twitter-atreply pret...    MALE  35-49
# 243  [La pasamos bien! A la noche nos juntamos en <...    MALE  25-34
# 245  [<a href="/marimarjimenez" class="twitter-atre...  FEMALE  25-34
# 249  [Espectacular vista de Mallorca desde Barcelon...  FEMALE  35-49
#
# [225 rows x 5 columns]

# %%
# some authors appear in the same dataset for two different languages
# the tweets are different
corpus16[corpus16['author'].isin(['60d21d384ea52074f685904742b8cd4e'])]
# Out:
#                               author lang  \
# 90  60d21d384ea52074f685904742b8cd4e   EN
# 4   60d21d384ea52074f685904742b8cd4e   ES
#
#                                                  text gender    age
# 90  [Spectrum con tarjeta ethernet <a href="/hasht...   MALE  35-49
# 4   [De <a href="/juleniturbe" class="twitter-atre...   MALE  35-49

# %%
# only pan14 and pan16 have duplicates (within and between), so always keep them as part of one split
# i.e. 14 and 16 should be in test or train, but not split between the two

# %%
corpus14, corpus15, corpus16, corpus17 = (pdl.clean_and_normalize(c) for c in [corpus14, corpus15, corpus16, corpus17])

# 298  99e4aebbe85cd43b556eb49858542e6d   en
# 299  becac0d89a5fe1fd565ace075ad52740   en
# 300  dd44957ee74db121a397cab2b4080379   en
# 301  3c3a39da1dd56313156d3f6c1a37a66e   en
# 302  30d04c264517f10e8bc1ff1fa85cc171   en
# 303  21a3849c161a739c6c7b557ca39ea04e   en
# 304  01f53025fddc8b3a8895c7ea38037662   en
#
#                                                   text gender    age
# 0    [The Internet Archive is now home to 10 petaby...      m  25-34
# 1    [Love, Loyalty and adventure.. Lost in the Mis...      f  50-64
# 2    [Healthy living is a mindset - get in the habi...      f  35-49
# 3    [Happy Moodle 2.1 Release Day! | Moodle News h...      f  25-34
# 4    [#Colombia: El Espectador critica en su editor...      m  35-49
# 5    [Hey! Y el EQUIPAZO DE MENTORES tb! #iw_castel...      f  35-49
# 6    [@Hostgator broke my site in the process of tr...      m  25-34
# 7    [Desengrasante http://instagram.com/p/geATIlRp...      m  35-49
# 8    [En dan verneem je plots dat je vermeld wordt ...      f  25-34
# 9    [Tax stuff is to the accountant!!  Makes you s...      m  50-64
# 10   [@bassoforhire http://www.amato.org , @SteveUm...      m  50-64
# 11   [research #developer #job in semantic web/link...      m  50-64
# 12   [How is tourism unethical? This web explain yo...      m  50-64
# 13   [Santa…can the digital economy save us?: http:...      m  50-64
# 14   [I'm at Cappuccino Lounge (Berlin) http://4sq....      m  35-49
# 15   [@TwoThirdsHazel ME TOO!!! It makes me so sad ...      f  25-34
# 16   [@alejandra_riba @Pasevlop @Brigi34 @AsunCarre...      f  35-49
# 17   [U.S. brushes off Iran-Iraq-Syria gas line htt...      f  35-49
# 18   [I can not live without coffee., 5 Typography ...      f  25-34
# 19   [Muy interesante: ¿Es el #Showrooming imparabl...      f  50-64
# 20   [Longmont is looking good these days! Our ranc...      f  35-49
# 21   [@ThomFain too easy. that wasn't as fun as i h...      f  25-34
# 22   [@WRadioColombia pena de muerte, @juanitakreme...      f  25-34
# 23   [@CIKM2011 @fcrestani We do! -> Accepted paper...      m  25-34
# 24   [♫ I'm a Fool to Want You – Billie Holliday ht...      f  50-64
# 25   [Remember to check your email address is somew...      f  25-34
# 26   [@inesbajo @goroji jajjajja! Lo sé!  Gracias S...      f  35-49
# 27   [Thinking About Fast Food and Flavor http://hu...      m  65-xx
# 28   [www.haxel.com and the new ICIC website http:/...      m  50-64
# 29   [Prepare your steel anus, Hehe mi culo por mat...      m  18-24
# ..                                                 ...    ...    ...
# 275  [Keys for doing business with Chinese supplier...      f  50-64
# 276  [Abraham Lincoln "Things may come to those who...      f  65-xx
# 277  [Is graphics finally mature for the web. WebGL...      m  35-49
# 278  [@jherskowitz we have a hack day coming up, I ...      m  35-49
# 279  [@lloydhollett Christmas comes early in your h...      m  25-34
# 280  [Academic English Solutions:  Writing the Resu...      m  50-64
# 281  ["@UxioMalvido: "What Does the New #HR Organiz...      f  35-49
# 282  [Browser stats, IE 42%, FF 28%, Chrome 22% - l...      m  35-49
# 283  [“@ArinataThub: @FlagEdgeDenim answer is mr. @...      m  25-34
# 284  [I Never get the Good One’s! How many Paper to...      f  35-49
# 285  [$$: Information Arbitrage - Sound thinking fo...      m  35-49
# 286  [Buscando zapatillas de running #fb (@ Decathl...      m  35-49
# 287  [Police Credit Social Media With Solving A Cre...      f  18-24
# 288  [#nowlistening Love, John Lennon http://m.yout...      f  35-49
# 289  [transfering technology to a new spin-off UPC ...      m  35-49
# 290  [Letters from 500 "Portal" http://wp.me/pI226-...      m  50-64
# 291  [I just joined LinkedIn and created my profess...      f  50-64
# 292  [Such a sweet painting! Happy to sell a giclee...      f  50-64
# 293  [Aprende a escribir tweets irresistibles #Twit...      f  35-49
# 294  [Just favorited 'De Howard Dean a Obama MAICOP...      m  50-64
# 295  [@mobal interesting. do you sell to Canadian c...      m  35-49
# 296  [@txinin estoy igual., Le cambiaron el nombre ...      m  25-34
# 297  [@mikehadlow i've been in erlang for the last ...      m  35-49
# 298  [@dwakabayashi Tx for follow, be sure to check...      f  35-49
# 299  [“@JobHits: Business Development Manager - Ban...      f  35-49
# 300  [Nice try fire extinguisher.  Don't try to get...      m  25-34
# 301  [Venga nenes, que hoy es sábado! A TOPE JODER ...      m  25-34
# 302  ['Nit Gin Jazz, la fusió perfecte. Clausura de...      m  35-49
# 303  [Come join us on Whidbey for "Spirited Work - ...      f  65-xx
# 304                                                 []      m  50-64
#
# [305 rows x 5 columns]

# %%
corpus14 = corpus14[corpus14['lang'] == 'en']
corpus15 = corpus15[corpus15['lang'] == 'en']
corpus16 = corpus16[corpus16['lang'] == 'en']
corpus17 = corpus17[corpus17['lang'] == 'en']

# %%
corpus14['text'] = corpus14['text'].apply(lambda x: "\n".join(x))
corpus15['text'] = corpus15['text'].apply(lambda x: "\n".join(x))
corpus16['text'] = corpus16['text'].apply(lambda x: "\n".join(x))
corpus17['text'] = corpus17['text'].apply(lambda x: "\n".join(x))

# %%
import pickle

with open("corpus15.pickle", "wb") as f:
    pickle.dump(corpus15, f)

# %%
with open("corpus15.pickle", "rb") as f:
    test15 = pickle.load(f)

# %%
set(test15['lang'])
# Out:
# {'en', 'es', 'it', 'nl'}

# %%
# corpus14['text'] = corpus14['text'].apply(lambda x: BeautifulSoup(x, "lxml").getText())
corpus16['text'] = corpus16['text'].apply(lambda x: BeautifulSoup(x, "lxml").getText())

# %%
for text in corpus14[corpus14['gender'] == 'm']['text']:
    print(text)
    break
# Out:
# The Internet Archive is now home to 10 petabytes of data http://zite.to/SpDcpU
# Big Data Right Now: Five Trendy Open Source Technologies http://zite.to/PzvxqJ
# Apple product rumours for 2013 http://zite.to/TnWtsJ
# How to Install WordPress on RackSpace Cloud Server Without Coding http://zite.to/U6Clrw
# My learnings from 500 Startups – the first month http://zite.to/SPKL7N
# First vertical farm opens in Singapore (Wired UK) http://zite.to/TMEJcw
# Amazon’s Aggressive Homepage http://zite.to/WU56Oq
# Google Launches Crisis Map for Hurricane #Sandy http://zite.to/PBR1TQ
# Amazon suit shows Google as public #cloud threat http://zite.to/Rgi0PT
# Tony Robbins: Change Your Words, Change Your Life http://lnkd.in/Nm8y_P
# How Automated Workflows 'Work': A Simple Setup Guide http://zite.to/QQpcnE
# Search Advertising Equates to $100 Million Daily for Google http://zite.to/VZ7hky
# Rackspace versus Amazon: The big data edition http://zite.to/QQqJdy  #cloud
# Google launches open source Voter Information Tool in advance of the 2012 US presidential elections http://zite.to/StoJcr
# Small business loves Facebook and Twitter, ignores LinkedIn, Google+, and Pinterest (infographic) http://zite.to/PDaZh2  #socialMedia
# UBS set to exit fixed income, fire 10,000 bankers http://zite.to/VzZt2F
# Europe Closes Red For 7th Day Of Last 8 (Shortly) http://zite.to/TQT01X
# Ticketing Startup SeatGeek Just Turned Profitable, Saw $2.5M In Ticket Sales Last Month http://zite.to/TQT5CK
# How Shutterstock Went From Zero to IPO http://zite.to/TQTipu
# More Proof That Startups That Hire Fast Are More Likely To Crash And Burn http://zite.to/TQTy81
# Canada is an Amazing Place to Launch a Startup, Entrepreneurs Affirm http://zite.to/YhXKSN
# Twitter offers free Promoted Crisis Tweets to @RedCross and more in wake of Hurricane Sandy http://zite.to/RstQbm
# Google’s Chrome Remote Desktop Screen Sharing Service Comes Out Of Beta, Adds Real-Time Audio For Windows http://zite.to/VZdMUf
# Why The Future Of Search May Look More Like Yahoo Than Google http://zite.to/WUKoOh
# These Are Google's Biggest Advertisers, Ranked By Dollars Spent Daily http://zite.to/RmvIAw
# Netflix rolls out Android app for Kindle Fire owners in the UK http://zite.to/PEXA8i
# What Startups are Top Internet Entrepreneurs Investing In? http://zite.to/YiaVDl
# First iPad Mini Reviews: "Shockingly Nice to Hold", Non-Retina Display, Pricier than Rivals http://zite.to/RuHavS
# Windows Phone 8 SDK Now Available To Download http://zite.to/Sbh2Fg
# Zetrip Finds Travel Photos And Recommendations From Your Facebook Friends, Raises Seed Funding http://zite.to/RuHjzH
# Google unveils new Siri-like voice search app for iOS http://zite.to/RuHpaj
# These Smart, Social Apps Bring Big Data Down to Size http://zite.to/Ym3xHb  #BigData
# This is what the reviews say about iPad Mini http://zite.to/QTEKap  #iPadMini
# Big Data for Small Businesses http://zite.to/SuC4SP  #BigData
# Facebook's New Listings Could Target LinkedIn And Craigslist http://zite.to/RwqwMr
# Facebook rolling out option for fans to receive notifications about page posts http://zite.to/PHYot5
# Microsoft Just Scored A Huge Win In The Cloud http://zite.to/VaM9Gz
# Gmail finally beats Hotmail according to third-party data [chart] http://zite.to/VaMGIt
# Google Translate Gets A Better Dictionary With Smarter Rankings, Reverse Translations And Grouped Synonyms http://zite.to/QVphqn
# Why Failure is So Important to Success http://zite.to/SxGbNV
# For ed tech startups, pudgy is better than lean, says Princeton Review founder http://zite.to/TYktos
# Google Earth for desktop gets tour guide feature and additional 3D imagery http://zite.to/SyIAqE
# Apple spends an extra $1 billion on research in 2012, still way less than competitors http://zite.to/RtP8Uf
# Important Updates for the Amazon Web Services Global Start-Up Challenge http://zite.to/TVHbYk
# Big Blue's Bet on Big Data http://zite.to/Tot8dc  #BigData
# Connecting Marketing & IT: 5 Tips for Creating a Shared Marketing Agenda with Your CIO http://zite.to/QWCGyi
# Facebook Testing New Timeline Format With Single Column of Posts [REPORT] http://zite.to/X3gK9J
# Baidu’s tricky transition to making money on mobile http://zite.to/Q89Kq6  #mobile #search
# The Dollar Shave Club Gets $9.8 Million From Investors http://zite.to/VewupF
# A great position in a great team! #job #emploi #montreal #marketing http://lnkd.in/SpYSBS
# A Good Quarter For Social Media: LinkedIn And Yelp Overachieve http://zite.to/QXTTHL
# Songza Connects Facebook Users To Mood Music http://zite.to/VfShxi
# 50% of Web Sales to Occur Via Social Media by 2015 [INFOGRAPHIC] http://zite.to/SsvbPq  #SocialMedia
# 8 Canadian Startups I would invest in if I was a VC http://zite.to/QXUpFx  #startup #canada #investment #vc
# Scaling Scala vs Java http://zite.to/Um3PcU
# What a stupid idea- Here's A New Way Google Wants To Replace Your Credit Cards
# http://www.businessinsider.com/google-wallet-card-2012-11 …
# Judge to Apple: Redo Samsung Apology Small Business Trends
# http://smallbiztrends.com/2012/11/apple-must-apologize-again-for-samsung-copycat-claim.html …
# Microsoft currently testing its own smartphone, says WSJ
# http://www.theverge.com/2012/11/2/3589212/microsoft-smartphone-testing-windows-phone-wsj …
# Google Wallet leak shows off new physical credit cards
# http://www.slashgear.com/google-wallet-leak-shows-off-new-physical-credit-cards-01255253/ …
# The 4 Phases Of Big Data http://lnkd.in/Q5--z6
# 10 Interesting Digital Marketing Stats We've Seen This Week http://zite.to/VHCyTc  #eMarketing
# Android now has 75 per cent of the smartphone market, according to Q3 results http://zite.to/SwnWGb
# This Map Shows Where Google Street View Has Gone So Far http://zite.to/YxfUjA
# LinkedIn Marketing: New Features to Enhance Your LinkedIn Results http://zite.to/RyPsDa  #SocialMedia #eMarketing
# Sony SmartWatch – merging watch and cell phone into one http://zite.to/SiMPnK
# Semantic Html With Twitter Bootstrap http://zite.to/Tmw4cx
# Bing vs. Google: Which Search Engine is Best? http://zite.to/TmwtvA
# Google loses appeal against French tax searches http://zite.to/TmwzmZ
# Google Declares Existing Web Metrics Obsolete: A Sea Change in Dealer Website Analytics http://zite.to/U6BIUp
# A Text-only Browser Powered by Google Scripts http://zite.to/SiB94s
# Facebook Execs Start Selling Stock: Sandberg Cashes Out Just 2% For $7.4M But CAO Dumps Half His Stake http://zite.to/WhyT4v
# HTC working on the official Facebook phone http://zite.to/RAHJ7A
# Big Data News of the Week http://zite.to/TBIRKk
# 5 Millimeter Thick, 2.5 Inch Hybrid Terabyte Hybrid Hard Drive Can Boost Memory For Tablets http://zite.to/U0BPeq
# The future of recruiting in the technology industry http://zite.to/WluvRO
# 5 Trends That Are Changing How We Do Big Data http://zite.to/VKg0kM  #BigData
# Remember to set your clocks back on November 4, 2012 http://zite.to/TqNF37
# Dollar Shave Club to Launch in Canada http://zite.to/XbSEtt
# Apple Only Paid 1.9% Tax On Foreign Earnings Of $37 Billion Last Year http://zite.to/UtNoet
# Apple drops to 50.4% tablet market share in Q3, as Samsung grabs 18.4% and Amazon takes 9.0% http://zite.to/TENR0K
# Remote Tech Support Firm, 24/7 Techies, Raises $600k Seed Round — Led By 500 Startups http://zite.to/UtNxPk
# iPad Mini Costs Apple $188 to Build According To Report http://zite.to/YuXeSL
# Bicycle Chain Charger to USB http://zite.to/PQQU71
# Siri can buy your movie tickets in iOS 6.1 http://zite.to/RDntSU
# Top 20 Downloaded #Free #Android #Apps http://zite.to/SsVuoa
# How to Optimize Images for Better Search Engine Rankings http://zite.to/YKVHHa  #seo
# 9 Tips to Turn an Idea into a Business http://zite.to/YwmoQH  #startup #entrepreneur
# Apple says it sold 3 million #iPads in 3 days, “practically sold out of iPad minis” http://zite.to/SP54or
# Sandy: Biggest Event in Instagram History http://zite.to/SP5pYq
# Instagram Adds Profile Pages, Now Looks Like Facebook http://zite.to/UuuTXn  #SocialMedia
# A Top Android Executive Admits Google Bought Motorola For The Patents http://zite.to/XeMCrQ
# Now You Can Upload Multiple iPhone Photos to Facebook at Once http://zite.to/TGDnhw
# Foursquare now gives 1-10 ratings for locations in its iOS app, becomes Yelp competitor overnight http://zite.to/XeNBZd  #LocalSearch
# Google’s share of UK search market dips below 90% http://zite.to/UveTV9  #search
# The Most Active #VCs in the #Arab World in 2012 http://zite.to/RFIRXC  #entrepreneur #investing #startup
# Building a #startup together with your investor http://zite.to/RPzPp5  #entrepreneur #investor
# #Siri Apple VS #GoogleVoice Search http://zite.to/UvfA0O  [video]
# Google #Maps losing market share in China http://zite.to/UvfCFO
# Google decline in China continues as its #search share falls to 4th place, maps to 6th http://zite.to/UvfE0o
# #Qihoo's New Search Engine Surges to 10% Share in China, Google Drops to 4th Place http://zite.to/UvfGWd
# How To Build A Strong Company Culture, From The Inside Out http://zite.to/Wv7xI7  #entrepreneur
# Russian Internet giant Yandex rolls out mapping service for Europe and the US http://zite.to/RGkqt4  #map
# Skype Is Replacing Windows Live Messenger http://zite.to/RfgoIf
# Why does Google shut down products? http://zite.to/VABq8x
# New Google Universal SERPs Layout Brings Apps to Forefront http://zite.to/YOp10z  #search
# Startups learn a painful lesson: The ‘Dropbox effect’ is a myth http://zite.to/SKYizj
# 25 #Entrepreneurs Tell What They Wish They'd Known before Founding Their First #Startup http://zite.to/TwclXN  via
# Twitter survives election after Ruby-to-Java move http://zite.to/STlL23
# 10 Canadian Tech Companies to Watch http://zite.to/VKkVa8  #startup #canada
# Catching Up With Exponential Labs, The Startup Behind Long-Tail Search Site ‘MillionShort’ http://zite.to/RodMYx  #search
# Google introduces six-month trial for #Cloud SQL, ups storage 10x to 100GB, adds EU datacenter http://zite.to/SxNGRF
# BDC Venture Capital Becomes Startup Weekend Canada’s First National Partner http://zite.to/Q1pBHn
# When Google Wants To Buy Your Startup, It Sends You An Email That Looks Like This http://zite.to/SPiYWP
# #BigData #Search And #Analytics Startup #ElasticSearch Raises $10M From Benchmark http://zite.to/Ta1RgU
# Social + Search: Building A Better Search Engine http://zite.to/Q1pNq1  #SocialSearch
# Apple Is Still On Top, But Seems Vulnerable http://zite.to/VQpdwL
# Google Ventures dedicates $1.5 billion to invest in startups, expands fund to $300 million a year http://zite.to/SS3OjI
# Anatomy of a Demo Day: FounderFuel’s fall 2012 cohort graduates (in pictures) http://zite.to/Ue11yb
# Spotify Said To Be Raising $100 Million At $3 Billion Valuation http://zite.to/UABpft
# Google is now a 'mobile first' company, execs say http://zite.to/Qwh2UO
# Box CEO: ‘Pinterest is better-designed than the software we run our businesses on’ http://zite.to/RLPEjZ
# Spotify Is Having A Good 2012: Revenues Could Reach $500M As It Expands The Digital Music Market http://zite.to/TSD1ED
# Google is back online in China after blocking http://zite.to/VS8bOO
# An Entrepreneur’s Guide To Patents: The Basics http://zite.to/VSOgPG
# Apple Settles Patent Suit With HTC http://zite.to/TzO3Ki
# Did This Clock Cost Apple $21 Million? http://zite.to/Z6zQLq
# To Understand Just How Much The Cloud Will Change The World, Look At Toyota http://zite.to/TU0Xr6
# 10 Tech Startups That Can Change Your Life http://zite.to/Rv0Yzz
# How To Send FREE SMS With Gmail To Any Mobile In Any Country? http://zite.to/SN7AZe
# How A Simple Gmail Search Could Lead To An Invasion Of Your Privacy http://zite.to/Q72Xx4
# Best Buy has spent 50,000 hours training its employees about Windows 8 http://zite.to/RRzoMN
# Microsoft releases Skype Preview for Windows Phone 8 http://zite.to/UjcBbn
# China’s Alibaba brings in a record $3.1b in sales during 24-hour e-commerce shopping frenzy http://zite.to/WWnqaM
# Google New Algorithm Added - Exact Match Domain (EMD) Penalty http://zite.to/UjdDUA
# Indian Firm Unveils $20 Tablet, Could Change the Industry Small Business Trends http://zite.to/TCxDRw
# DataSift lands $15 million to help enterprise firms find sense and order among social data http://zite.to/T16s7v  #BigData
# The Wall Street Journal launches The Accelerators and Startup Journal to cover entrepreneurship http://zite.to/Twda3k
# Google makes more money from ads than print media combined http://zite.to/SQI2dQ
# 5 Areas That Demonstrate The Growing Potential Of #LocalSearch http://zite.to/UA7SIr
# [Survey] How Consumers Are Using #LocalSearch http://zite.to/UA8kWU
# Get funded! An idiot’s guide to mastering the venture capital game http://zite.to/RU2lYx  #vc #investment #entrepreneur
# Pitch Preparation: What VCs Are Looking For http://zite.to/UDHmbr  #vc #funding #entrepreneur #startup
# Microsoft May Be Making a Smartphone for China http://zite.to/W2Izi0
# Google Introduces 'Shortlists' for Collaborative Shopping http://zite.to/Un5PBi
# Nokia will make Android SDK available to developers who wish to use its new Here maps in their apps http://zite.to/SkDThv
# Attend a free webinar for global entrepreneurship week with Palo Alto Software http://zite.to/T2q8Im
# 4 Investors Share What Makes Them Open Up Their Wallets For Startups http://zite.to/TYqpvM  #entrepreneur #startup #investment
# Text messaging falls for first time in U.S. http://zite.to/TYqfEz
# Dropbox Passes 100 Million Users http://zite.to/TDabn2
# Nokia's New Mapping Service Is Coming to iOS and Android http://zite.to/RSdF98
# US Public Perception of Bing #Search Engine Up http://zite.to/QG3LZM
# Who Is Julie Larson-Green, Microsoft's New Windows Boss? [VIDEO] http://zite.to/QG4330
# Airbnb Moves into the Travel Guide Business http://zite.to/RW8HH1
# Stacy:Parkinson http://lnkd.in/FubQ9V
# Facebook launches Social Jobs, a job search app http://zite.to/TI8IP2
# The Best Startup Pitches Of All Time http://zite.to/SWqwoE
# How to Measure Your #SocialMedia Traffic Using #GoogleAnalytics http://zite.to/XIbjNO
# Android crushes the competition in China as it passes 90% smartphone market share: Report http://zite.to/T437on
# Gmail Enables Search By Date and Size http://zite.to/TKgAiA
# Yandex launches new iPad app to make #search faster and easier for tablet users http://zite.to/XIc8Gq
# 5 Lessons Learned from Chinese #Startup Failures http://zite.to/ZxTe48
# Apple's Stock Price Crashes To Six Month Low And There's No Bottom In Sight http://techcrunch.com/2012/11/15/apples-stock-price-is-crashing-and-the-bottom-is-not-in-sight/ …
# Viral Videos: How to Create and Promote Videos People Love http://zite.to/SZSBv7
# Hey, enterprise #startups! Microsoft CEO Steve Ballmer will hear your elevator pitch http://zite.to/XL94cr
# Twitter Updates its iOS and Android Apps, Enhances Search http://zite.to/RGns0C
# Twitter Makes #Search Results More Visual With Top Photos, Videos & Instant Previews http://zite.to/XKrGJF
# WSJ: Google Is Putting The 'Finishing Touches' On Google #Maps For iPhone http://zite.to/XLR8hN
# Entrepreneurshit. The Truth About Building Starutps http://zite.to/XLSmtt  #entrepreneur #dtartup
# Facebook Is Quietly Ramping Up A Product That 'Kills Us' Says Yahoo Source http://zite.to/RHQvBa
# Google adds 3D in #Maps, #Earth for 60 more cities worldwide http://zite.to/UvRxyd
# Google: Developers Get Double Learning Dose http://zite.to/UL7jLV
# A Startup You've Never Heard Of Called Supercell Is Suddenly Worth $600 Million http://zite.to/ULMTSR
# 40 Engineers Worked 14-Hour Days, 7 Days A Week To Get Obama Reelected http://zite.to/TJIhGf
# We’re Getting Very Close To The Perfect MacBook http://zite.to/XmO64G
# The 3 Best Places To Legally Watch Free Movies Online http://zite.to/ZPqGUa
# Dropbox, SkyDrive, Google Drive and Box http://zite.to/XmY2LJ
# The #Canadian #Startup Awards are Back http://zite.to/UO5MEE  via @zite
# Marissa Mayer And Sheryl Sandberg Are In Secret Talks To Make A Facebook/Yahoo #Search Engine http://zite.to/WlSSy7
# A Yahoo-Facebook #Search Engine Would Be A Brilliant Move For Both Companies--Here's Why http://zite.to/QR3R0S
# The legendary pivot: How Twitter flipped from failure to success [video] http://zite.to/Q4s2aT
# Which Tablet to Buy Among Dozens Confuses Shoppers http://zite.to/UBljSv
# Search #GoogleDrive from Chrome’s address bar http://zite.to/TbdPtf
# Checkout Montreal's startup map: coworking spaces, investors, events, influencers  http://startupguide.ca  #startupguide via @mtlstartupguide
# How to Get #Startup Ideas http://zite.to/TUHe8u  #entrepreneur
# Groupon Makes Bid To Become Local (Deals) Search Engine http://zite.to/Tcloit
# This BlackBerry 10 Handset “Leak” Looks Awfully Staged http://zite.to/RP4pS7  #bb10
# The Truth Is That Being An #Entrepreneur Is Completely Horrible http://zite.to/SIRH5A
# Apple opens its first eBay store for a trial with select refubished products http://zite.to/UbtOrc
# Alternatives for Google Mini #Search http://zite.to/Xwb6yn
# Headphone Splitter lets you share sound with friends http://zite.to/10kWW0u
# Google announces ‘Arabic Web Days’, a month-long initiative to boost Arabic Web content http://zite.to/Q8iawB
# Microsoft to shut down Messenger on 15 March, move users to Skype http://zite.to/ZGx7dU
# Google FTC Decision and What It Means for You http://zite.to/VG49oW
# Who is #Canada's Best New #Startup? http://zite.to/VLUT4W
# Google’s location-aware Field Trip tour guide app now serves up local deals, courtesy of Scoutmob http://zite.to/11iLrtH
# How to Generate Leads With SlideShare http://zite.to/UYg6Im  #SpcialMedia #eMarketing
# Shopping via mobile devices increased 81 percent in 2012 http://zite.to/WuH8E8
# YAHOO Mail And Search Traffic Are Dropping Staggeringly Fast http://zite.to/ZJpVha
# #SEO Link Building Best Practices for 2013: Interview with Neil Patel http://zite.to/UCZd3d
# Here's A Great Philosophy On How To Build A #Startup http://zite.to/UQdS0m
# Eventbrite’s 2012: 36M Tickets Sold; $600M In Gross Sales http://zite.to/UZ0zIc
# Netflix shows off its #Hadoop architecture http://zite.to/TOad0e
# Lessons about Building a Team from Zuckerberg and Facebook http://zite.to/RJzR6z  #TeamBuilding
# #Canada Has Some of the World's Best #Startup Ecosystems. Here's How to Make Them Even Better http://zite.to/V26EU7
# Apple takes no prisoners, immediately blocks Java 7 on OS X 10.6 and up to protect Mac users http://zite.to/11nE18n
# Will Europe Force Google to Change How it Displays Search Results? http://zite.to/VSo0DL
# 4 Signs That Your #Startup Is Ready To Pivot http://zite.to/Spj9uT  #entrepreneur
# Releases December 2012 U.S. #Search Engine Rankings http://zite.to/VSoiKP
# Online Media Daily: Google To Build AI Into Search http://zite.to/Sphaqw
# Analyst: #Mobile Continues To Take Share From Desktop #Search http://zite.to/WxFamx
# StartupsBio.me Maps Out the Global #Startup Ecosystem http://zite.to/V1L5Df
# Now at 50m users, LinkedIn rival Viadeo acquires French startup Pealk and announces US innovation lab http://zite.to/UKsUiK
# Helpful #Instagram #Analytics Tools, and Other Marketing Stories of the Week http://zite.to/W1NAE0  #emarketing
# Oracle ships Java 7 Update 11 with vulnerability fixes, increased security level for Java applets http://zite.to/V4cG9K  #java7
# Cars Are The Next Playground For App Developers http://zite.to/VEyU0m
# Facebook’s Tuesday event fuels “Facebook phone” rumor http://zite.to/SuUXHm
# 8 #Startup Events and News to Watch This Week http://zite.to/V97TRw  #entrepreneur
# #Startups, take note: An IPO is a surefire way to lose your innovative edge, says Stanford study http://zite.to/X0C6PK
# Super Advanced Not Provided Keywords Analysis in Google Analytics http://zite.to/VXTEzC
# 77 Percent Of Online Health Seekers Start At Search Engines [Pew Study] http://zite.to/TXhHhI
# Github passes 3m registered users, adds 1.3m sign-ups since raising $100m in July http://zite.to/VZymBX
# Yelp begins adding restaurant inspection scores to listings, starting in San Francisco and New York http://zite.to/U3im15  #LocalSearch
# Local Business Calling; Is Google Further Monetizing Local? http://zite.to/XbTUrd  #LocalSearch
# LoopMe raises $500,000 to organize mobile ads into a smart, unobtrusive inbox http://zite.to/U2dKID
# Hack Design Teaches Design To Hackers, Has Already Signed Up Over 20K Developers http://zite.to/XbWH3B
# 9 #Startup Events and News to Watch This Week http://zite.to/11Lgz58
# Google Goes Shopping, Buys Channel Intelligence for $125 Million http://zite.to/WSobfE
# Yelp Reports Q4 Losses As Local Gets More Crowded Than Ever http://zite.to/WA1heJ  #LocalSearch
# Suddenly Google Is Going To Sell Ads On Yahoo http://zite.to/VEWerl
# LinkedIn eyes future as professional publishing hub http://zite.to/14GKRVB
# MyKids360 is looking for a designer for web or mobile apps #swmontreal
# MyKids360 is looking for a designer for web or mobile apps #swmontreal
# MyKids360 is looking for a designer for web or mobile apps #swmontreal
# MyKids360 is looking for a designer for web or mobile apps #swmontreal
# @mhhalle check your e-mail. I NEED you!!!
# HELP: I am working to build the best mobile app for new parents and babies and would love to get your opinion in this …http://lnkd.in/6qXu5M
# I am building a #mobileApp for new #parents and #babies and would love to get your opinion in this VERY short survey: http://svy.mk/URymWT
# #Mobile #App for new #parents [Survey] http://svy.mk/URymWT
# #Mobile #App for new #babies [Survey] http://svy.mk/URymWT
# @newparentsnetwo am building a mobile app for new parents and would love to get your opinion in this VERY short survey:http://www.surveymonkey.com/s/K9ZMGSG
# @NewlyParents am building a mobile app for new parents and would love to get your opinion in this VERY short survey:http://www.surveymonkey.com/s/K9ZMGSG
# Sorry for the abrupt ending to the #swmontreal #nokTOK presentation. The best was yet to come...hope you liked it though...
# I have over 10,000 views on SlideShare!
# Looking for #Java developers #ContentManagement #DB #API #Montreal #Jobs
# I'm looking for Java developers to work on great project about Search and Content Management #java #montreal #job: http://lnkd.in/a4y3Re
# 10 Ways to Kickstart Your Business Today http://zite.to/XD11ta
# Zuckerberg Now Owns 29.3 Percent Of Facebook, Representing $18 Billion http://zite.to/11KdbbS
# Decoding the Deadpool: How to Tell When a #Startup Has Failed http://zite.to/12vSNe8
# Steve Blank on 'continuous innovation': Tech companies aren't solving 21st century problems http://zite.to/XgHfnW
# How To Use Mailbox, The New Email App For iPhone Everyone Is Talking About http://zite.to/XfYciv
# Indoor Google Maps For Android Now Available in Singapore http://zite.to/XqPuzP
# How to Identify an Online Community for Your Business http://zite.to/YjTiAq
# How to write great marketing copy for your startup http://zite.to/UCyZSF
# http://Outlook.com  Officially Replaces Hotmail, Boasts 60M Users http://zite.to/W0R4eI
# Alibaba’s new Aliyun search engine raises the stakes in its feud with Google and Android http://zite.to/XJLKGV
# Apponomics: 7 ways to make money from apps without ads http://zite.to/ZbyeyP
# 20+ Signals That Make Your Business Easier To Find in Local Search Engines http://zite.to/12ZdvmG
# #Job #Montreal #Architect #IT http://lnkd.in/DMhKye
# Looking for Java Developers #Search #ContentManagement #DAM #Solr #Lucene #NLP #Oracle #Montreal
# Firefox to follow Safari, start blocking cookies from third-party advertisers http://zite.to/ZrEVwU  #eMarketing #TargetedMarketing
# Work from home no more: How do you feel about Yahoo's crackdown? http://zite.to/133ouM4
# Google has a problem with "long-tail" #searches, and it needs Quora to help fix it http://zite.to/15boSX4
# Looking for a Project Manager #IT #ContentManagement #SystemsIntegration #Job #Montreal
# Job opportunity: Senior Java Developer – Content Manageme at Yellow Pages Group / Gro - Montreal, Canada Area #jobs http://lnkd.in/g8RjCE
# Job opportunity: Senior Project Manager – Content Managem at Yellow Pages Group / Gro - Montreal, Canada Area #jobs http://lnkd.in/Vfdse8
# Intel unveils a fast dual-core Atom processor for smartphones and tablets http://zite.to/138Seax
# The most overlooked element of your #startup: The brand http://zite.to/13gjWlv
# 6 Tips on How to Use Twitter’s New Vine Video App for Marketing http://zite.to/ZtfvyX
# Mozilla Launches Firefox OS For Mobile, Challenging Apple And Google With The Open Web http://zite.to/XV4a7J
# I have one available ticket for Diana Krall for this evening #montreal #mtl #DianaKrall #concert
# Adobe brings Photoshop Touch to iPhone & Android so you can edit photos on the go http://zite.to/XZRsop
# Indian Startup DepartedLife is a Social Network for Dead People http://zite.to/YCaGo6
# Yelp: We compete with print -- not Google or Facebook http://zite.to/V7k3w4
# Apple Stock Just Crashed To A New Low http://zite.to/13uFPxz
# Yahoo Clues, App Search & Other Products To Shut Down April 1 http://zite.to/13whhEw
# Hitwise: Google Has Top Mobile Website And 5 Of The Top 10 http://zite.to/Y5oIL1
# Startup Launches Cloud-based Real Estate Analysis Software for Investors, Agents, and Brokers http://zite.to/Y5oJP0
# With 200 million members LinkedIn is now valued at more than $18 billion http://zite.to/Z6VsEl
# Want To Build A $1B Consumer Company? Look For Long-Haul Founders And Don’t Fear Incumbents http://zite.to/ZbhreM
# How Facebook indoctrinates every new engineer it hires http://zite.to/ZVVYv1
# Apple Just Lost $450 Million http://zite.to/VZmZtY
# ...
# YouTube says it will bring its creative studio space to New York City in 2014 http://zite.to/15zfzkM  via @zite
# Codementor Is An Open Marketplace That Provides Developers With One-On-One Programming Help http://zite.to/19APINi
# LinkedIn Wants To Ramp Up Ads With An Advertising API Like Twitter’s And Facebook’s; A ‘High Priority’ Say… http://zite.to/14muLVp
# A Look at Google's 200 Search Ranking Factors (Infographic) http://zite.to/18UYTJb
# Wall Street Darling LinkedIn Beats Estimates Again, Revenue Booms 59% To $363M, Now At 238M Members http://zite.to/13qQQzE
# Yahoo's Marissa Mayer: Search is far from over http://zite.to/14K2Yr2
# LinkedIn Rolls Out Enhanced Analytics Suite for Businesses http://zite.to/19ANRIC
# 7 Ways to Optimize Your Google Places Listing for More Traffic – Shopify http://zite.to/15hRMIv
# Twitter Launches Its Version Of Universal Search Results http://zite.to/16cjpzp
# HootSuite Lands $165 Million Financing For Social Media Management http://zite.to/12JkPEv
# Google Launches Real-Time API For Analytics In Invite-Only Beta http://zite.to/17mmdZI
# Android reaches massive 80% market share, Windows Phone hits global high, iPhone languishes http://zite.to/13yHMVH
# Facebook’s Graph Search Becomes A Job Recruiting Tool In Work4 Labs’ Graph Search Recruiter Beta http://zite.to/1360DqY
# Google-Inspired Resume Puts New Spin on Job Searches http://zite.to/14K4mKh
# How Website Speed Actually Impacts Search Ranking http://zite.to/19zeEVt
# NetBeez Is An Enterprise Network Monitoring Startup Using Raspberry Pis To Simulate Users http://zite.to/1cvsEzc  via @zite
# Google launches City Expert program to compete with Yelp http://zite.to/16SPuMv  #LocalSearch
# Zoho Introduces a Small Business CRM With "Pay What You Want" Pricing http://zite.to/14IRXej
# How Google could have made the Web secure and failed -- again http://zite.to/15uoMJg
# http://Academia.edu , The Social Networking Platform For Researchers, Raises $11.1 Million http://zite.to/1fqrlWg
# 5 Things You Should Know When Pricing Your Seed Round http://zite.to/173ip36
# Here's how expensive it is to run a startup in these 8 major cities (infographic) http://zite.to/1eIVOO4
# Here's The Secret To Building A Great Startup Team http://zite.to/18qSK2K
# 7 Stats Proving Google's Global Internet Domination http://zite.to/18xnYFw
# The Cutest Marketing Ever! 10 Adorable Campaigns to Brighten Your Friday http://zite.to/15zFuH9
# New Microsoft Surface 2 Tablets Have Arrived http://zite.to/199aVrY
# Yelp reveals its algorithm discards 25% of user reviews for being fake http://zite.to/18vTl38
# Google Hotel Finder & The War for Hotel SERP Listings http://zite.to/161AUVQ
# Google Glass competitor Recon Jet Gets Intel investment, Hints at Apple Connection http://lnkd.in/bbe8WSi
# Google launches Analytics Academy, offering free community-based video courses about digital analytics http://lnkd.in/bMXKiGC
# Soon you can use your Facebook credentials to log into Wi-Fi networks http://zite.to/GzX1cD
# Samsung's Clone Of Google's App Store Now Takes PayPal http://zite.to/173EUla
# Scientists Used Facebook To Gain Unprecedented Insights Into How We Use Language http://zite.to/1aLgXlP
# Let the music play: Google Music for iOS reportedly coming in October http://zite.to/19XhAXf
# Is Google Glass the Future of Healthcare? http://zite.to/157ekdq
# Samsung's $299 HomeSync box adds storage and smarts to your dumb TV http://zite.to/1fLGl17
# Google Buys Flutter, a Gesture Control Startup http://zite.to/19XibYR
# Rdio takes on Pandora and iRadio with free station streaming on iOS and Android http://zite.to/16Iuayx
# Facebook expands API program to help international broadcasters display user content in TV shows http://zite.to/1fWD92U
# Rocket Internet Launches Real-Estate Listings Site Lamudi In Asia, Africa And Latin America http://zite.to/GKLSoj
# Amazon Web Services Wins Again In Battle To Build The CIA And NSA Cloud http://zite.to/19wJ9Wx
# Yahoo Releases New Seach Experience For iOS Devices http://zite.to/16Pk52L
# Microsoft and HTC: Microsoft Wants HTC to Run Windows http://zite.to/19vvV24
# IT Spending to Reach $3.8 Trillion Next Year, as Billions of Things Get Connected http://zite.to/GJLRlw
# Google Introduces Local (Inventory) Product Listing Ads http://zite.to/16OywEp
# Google hides keywords from marketers: The complete guide to using alternatives from the experts http://zite.to/1cot3oT
# Google's Matt Cutts: No More PageRank Updates This Year http://zite.to/18Kk9Ot
# LG says it is ready to begin producing the ‘world’s first’ flexible screen for smartphones http://zite.to/1gkvZ6i
# Samsung Goes First, Google Experiments And Apple Refines http://zite.to/1hBD67W
# Crowdfunding 101: Don't forget to protect your idea http://zite.to/1cuFHmw
# We are hiring! #Job #montreal #BusinessDev http://lnkd.in/bPt7cDz
# we are hiring an Automation Specialist #job #montreal #It #DevOps http://jobs.ypg.com/ca/montreal/it/jobid4234612-automation-specialist-jobs …
# Instagram Adds Sound and Data Usage Controls to iOS, Android Apps http://zite.to/19DZKOh
# World's largest e-commerce company Alibaba leads $206M investment in Amazon competitor ShopRunner http://zite.to/1hGovrZ
# Facebook facing lawsuit claiming it scans users’ ‘private’ messages without consent http://zite.to/1cLJWc6
# Big Data and analytics: The year ahead http://zite.to/JxbTtp
# Open Data Now: Hottest Contenders for 2014 http://zite.to/18YpTrD
# Mobile Trends and Search Changes http://zite.to/1g8qbeP
# Zynga is testing Bitcoin payments for its Web games http://zite.to/1iDgOYz
# Google+ Local Optimization: What You Should Know http://zite.to/1avCmOG
# Foursquare details how it rewards and punishes its superusers http://zite.to/19U1QIt
# An Introduction to Hadoop 2.0: Understanding the New Data Operating System http://zite.to/19TDJK6
# The Internet Archive is now home to 10 petabytes of data http://zite.to/SpDcpU
# Big Data Right Now: Five Trendy Open Source Technologies http://zite.to/PzvxqJ
# Apple product rumours for 2013 http://zite.to/TnWtsJ
# How to Install WordPress on RackSpace Cloud Server Without Coding http://zite.to/U6Clrw
# My learnings from 500 Startups – the first month http://zite.to/SPKL7N

# %%
with open("all_english_female.txt", "w") as f:
    for c in [corpus14, corpus15, corpus16, corpus17]:
        for text in c[c['gender'] == 'f']['text']:
            f.write("{}\n".format(text))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import FeatureUnion
from sklearn.svm import LinearSVC

training = pd.concat([corpus15, corpus15, corpus16])
training = training[training['lang'] == 'en']
test = corpus17
test = test[test['lang'] == 'en']

# char_vec = TfidfVectorizer(analyzer='char', ngram_range=(2,6))
word_vec = TfidfVectorizer(ngram_range=(1,3), binary=True)

vectorizer = FeatureUnion([
    ('word', word_vec)
    # ('char', char_vec)
])

# %%
from collections import Counter
types = Counter([type(x) for x in test['text']])
print("test types: {}".format(types))
types = Counter([type(x) for x in training['text']])
print("training types: {}".format(types))
types = Counter([type(x) for x in training['text'] + test['text']])
print("merged types: {}".format(types))

types = Counter([type(x) for x in pd.concat([training['text'],test['text']])])
print("merged types 2 : {}".format(types))
# Out:
# test types: Counter({<class 'str'>: 3600})
# training types: Counter({<class 'str'>: 732})
# merged types: Counter({<class 'float'>: 3172, <class 'str'>: 732})
# merged types 2 : Counter({<class 'str'>: 4332})

# %%
vectorizer.fit(pd.concat([training['text'], test['text']]))
# Out:
# FeatureUnion(n_jobs=1,
#        transformer_list=[('word', TfidfVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None))],
#        transformer_weights=None)

# %%
X_train = vectorizer.transform(training['text'])
y_train = training['gender']
X_test = vectorizer.transform(test['text'])
y_test = test['gender']

# %%
X_train.shape
print(X_test.shape)

# %%
from sklearn.metrics import classification_report
from sklearn.svm import SVC
svm = SVC(kernel='linear', probability=True)
svm.fit(X_train, y_train)
preds = svm.predict(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB(alpha=0.001)
nb.fit(X_train, y_train)
preds2 = nb.predict(X_test)

# %%
print(classification_report(y_test, preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a6002ebc4cd7> in <module>()
# ----> 1 print(classification_report(y_test, preds))
#
# NameError: name 'classification_report' is not defined

# %%
Counter(y_test)

# %%
Counter(y_train)

# %%
Counter(preds)

# %%
probs = svm.predict_proba(X_test)

# %%
female_looks_male = [(x[1], i) for i,x in enumerate(probs) if y_test[i]=="f" and x[1] > 0.50]
print(sorted(male_looks_female, reverse=True)[:10])
# Out:
# [(0.89800115850759787, 524), (0.86119659576805552, 918), (0.85948208740317422, 2617), (0.85948208740317378, 774), (0.85319799964626375, 2948), (0.84333002415841807, 2019), (0.83300630655402697, 2256), (0.82832491272958053, 2343), (0.81426756875048423, 498), (0.79851783521847131, 2765)]

# %%
print(test.iloc[524])
print(test['text'].iloc[524])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-e31f4540c572> in <module>()
# ----> 1 print(test.iloc[524])
#       2 print(test['text'].iloc[524])
#
# NameError: name 'test' is not defined

# %%
print(test['text'].iloc[918])
# Out:
# Embrace your whole self! "The more I like me, the less I want to pretend to be other people." Jamie Lee Curtis #NimbleQuotes
# Want to truly master something? "...the way of the Master consists in doing one's best...that is all." Confucius #NimbleQuotes
# There is no growth without change. "[Be] strong enough and smart enough to let go and grow." Marc and Angel Chernoff #NimbleQuotes
# There is no substitute for wisdom. "There's a beauty to wisdom and experience that cannot be faked." Amy Grant #NimbleQuotes
# Will you express yourself? "Now it is your turn." Laura Probert #NimbleQuotes
# Keep an open mind. "The soul should always stand ajar; ready to welcome the ecstatic experience." Emily Dickinson #NimbleQuotes
# Indulge in learning and thought! "The noblest pleasure is the joy of understanding." Leonardo da Vinci #NimbleQuotes
# Progress never stops, life carries on. "Nature does not hurry, yet everything is accomplished." Lao Tzu #NimbleQuotes
# Learn more to give more and forever. "Education is the best provision for old age." Aristotle #NimbleQuotes
# We all need warmth, time and communication. "The combination of these gifts is pure intoxicating delight." Laura Probert #NimbleQuotes
# Keep trying until you do it! "Failure is a word I don't accept." John H. Johnson #NimbleQuotes
# How's your self-talk? "Your thoughts, the way you think is the most powerful influence in your life." John Patrick Hickey #NimbleQuotes
# Embrace what makes you smile. “If you smile when no one else is around, you really mean it.” Andy Rooney #NimbleQuotes
# Stay young at heart! "You're never too old to be young." Snow White from Snow White and the Seven Dwarfs #NimbleQuotes
# Your expectations become reality. "Expect more than others think is possible." Claude Bissell #NimbleQuotes
# Fear not the storm but learn to sail in it. "All great changes are preceded by chaos." Deepak Chopra #NimbleQuotes
# Life has miracles for those who look. "Don't believe in miracles; depend on them." Laurence J. Peter #NimbleQuotes
# Aim high. "Aim for the moon. If you miss, you may hit a star." W. Clement Stone #NimbleQuotes
# Let's fight for what we believe in. "Ready for battle." Laura Probert #NimbleQuotes
# Do you live simply? "I believe that a simple and unassuming manner of life is best for everyone..." Albert Einstein #NimbleQuotes
# Live your life with the passion that matters to you. "The big secret in life is that there is no big secret." Oprah Winfrey #NimbleQuotes
# The top is in our reach.  "It is within everyone's grasp to be a CEO." Martha Stewart #NimbleQuotes
# Embrace change in your work and life, "Open your arms to change, but don't let go of your values." Dalai Lama #NimbleQuotes
# Wake each day with this attitude: "My eyes with new gifts to discover and see." Laura Probert #NimbleQuotes
# Be open to new ideas. "It is the mark of an educated mind to be able to entertain a thought without accepting it." Aristotle #NimbleQuotes
# Who teaches you now? "Every child grows, everything depends on the teacher." Shinichi Suzuki #NimbleQuotes
# Give loved ones the honor of your attention. "The first duty of love is to listen." Paul Tillich #NimbleQuotes
# Smile and watch the world be happy! "I believe that when you put a smile out there, you get a smile back." Heidi Klum #NimbleQuotes
# Do you have faith? "Accept what is, let go of what was and have faith in what could be." Marc and Angel Chernoff #NimbleQuotes
# We learn to look past faults. "Love is blind; friendship closes its eyes." Friedrich Nietzsche #NimbleQuotes
# The best decisions need facts and reasons. "Judge behavior, not motives." Miles Anthony Smith #NimbleQuotes
# Tomorrow is a new day. "My next morning might provide." Laura Probert #NimbleQuotes
# Never ever give up hope. "Even miracles take a little time." The Fairy Godmother from Cinderella #NimbleQuotes
# There are lessons to learn "Don't bury your failures, let them inspire you." Robert Kiyosaki #NimbleQuotes
# Find your something! "We all have something that we are meant to do." Robin Sharma #NimbleQuotes
# You have only yourself to overcome. "Real learning comes about when the competitive spirit has ceased." Jiddu Krishnamurti #NimbleQuotes
# Learn, plan and do.  "I have to trust what I do, and then do it." Ednita Nazario #NimbleQuotes
# Choose to be the best.  "No one can make you feel inferior without your consent." Eleanor Roosevelt #NimbleQuotes
# Know the joy of giving a hand. "What do we live for, if it is not to make life less difficult for each other?" George Eliot #NimbleQuotes
# The joy of laughter improves love. "To laugh yourself is to love yourself." Mickey Mouse #NimbleQuotes
# Do the work of a leader. "Leadership is an action, not a position." Donald McGannon #NimbleQuotes
# Will reversing let you move forward? "Sometimes you have to take a step back to move forward” Erika Taylor #NimbleQuotes
# We must challenge and be challenged to grow. "I have never learned from a man who agreed with me." Robert A. Heinlein #NimbleQuotes
# Peace of mind creates happiness. "Learn to be calm and you will always be happy." Paramahansa Yogananda #NimbleQuotes
# Your calling, find it, love it, do it.  "Do what you love and the money will follow." Marsha Sinetar #NimbleQuotes
# Always choose to look ahead. "Some people cannot stand that you're moving on with your life..." Marc and Angel Chernoff #NimbleQuotes
# Learn to connect. "They may forget what you said, but they will not forget how you made them feel." Carl W. Buechner #NimbleQuotes
# Reach out fearlessly. "But, what if?...Jump, even while you are asking." Laura Probert #NimbleQuotes
# What move will you make? "It's the move you make, mind to heart to body parts." Laura Probert #NimbleQuotes
# Do it! One step at a time! "What saves a man is to take a step. Then another step." Antoine de Saint-Exupery #NimbleQuotes
# Create a great you! "You are essentially who you create yourself to be..." Stephen Richards #NimbleQuotes
# We need both. "Travel, in the younger sort, is a part of education; in the elder, a part of experience." Francis Bacon #NimbleQuotes
# Books can push your start button. "A book is a device to ignite the imagination." Alan Bennett #NimbleQuotes
# Passion gives power to your dream! "Ambition is a dream with a V8 engine." Elvis Presley #NimbleQuotes
# Revel in the magic of life. "Fully enjoy the wonder and beauty of each moment." Paramahansa Yogananda #NimbleQuotes
# Build your opportunities.  "If you don't like the road you're walking, start paving another one." Dolly Parton #NimbleQuotes
# Are you truly happy? “Learn to value yourself, which means: fight for your happiness.” Ayn Rand #NimbleQuotes
# Don't complicate: "Everything should be made as simple as possible, but not simpler." Albert Einstein #NimbleQuotes
# See as much of it as you can! "The world is a book and those who do not travel read only one page." Augustine of Hippo #NimbleQuotes
# We need stillness to think clearly. "I rest easy into my still self and breathe." Laura Probert #NimbleQuotes
# Make changes that matter! "We're here to put a dent in the universe. Otherwise why else even be here?" Steve Jobs #NimbleQuotes
# Life is a search. "We search something permanent, something that will last." Jiddu Krishnamurti #NimbleQuotes
# Love and grow.  "The greater your capacity to love, the greater your capacity to feel the pain." Jennifer Aniston #NimbleQuotes
# Inspire those near you! "I am not a teacher, but an awakener." Robert Frost #NimbleQuotes
# Good choices produce better futures. "I am not a product of my circumstances. I am a product of my decisions." Stephen Covey #NimbleQuotes
# Be confident! "You know, you do need mentors, but in the end, you really just need to believe in yourself." Diana Ross #NimbleQuotes
# Keep climbing. "The man on top of the mountain didn't fall there." Vince Lombardi #NimbleQuotes
# Be kind.  "As much as we need a prosperous economy, we also need a prosperity of kindness and decency." Caroline Kennedy #NimbleQuotes
# Intelligent choices matter. "...all that occurs in your life is the result of your own making." Stephen Richards #NimbleQuotes
# Trust; make choices - it is all possible. "I am where I am because I believe in all possibilities." Whoopi Goldberg #NimbleQuotes
# Make inspiration come to you. "You can't wait for inspiration. Sometimes you have to go after it with a club." Jack London #NimbleQuotes
# Take pride! "Change not only was inevitable, but usually brought its own rewards." Nicholas Sparks #NimbleQuotes
# The echoes of bounced ideas can grow.  "Ideas are like pizza dough, made to be tossed around." Anna Quindlen #NimbleQuotes
# I decide. "Failure will never overtake me if my determination to succeed is strong enough." Og Mandino #NimbleQuotes
# Boldness and courage are vital for achieving dreams. "Anything's possible if you've got enough nerve." J.K. Rowling #NimbleQuotes
# Always strive for your best. "Doing the best at this moment puts you in the best place for the next moment." Oprah Winfrey #NimbleQuotes
# Work through adversity. "The best way out is always through." Helen Keller #NimbleQuotes
# Shine! "The beauty of a woman is seen in her eyes...the doorway to her heart, the place where love resides." Audrey Hepburn #NimbleQuotes
# Does chaos hide the answers we seek to discover? "From discord find harmony..." Albert Einstein #NimbleQuotes
# Love yourself! "Life is too short to spend at war with yourself." Marc and Angel Chernoff #NimbleQuotes
# Freedom is happiness. "Nothing is more precious than independence and liberty." Ho Chi Minh #NimbleQuotes
# Be swallowed by your craft. "I don't do fashion, I am fashion." Coco Chanel #NimbleQuotes
# Which are you? "...some are born great, some achieve greatness, and some have greatness thrust upon them." William Shakespeare #Array
# Always take chances! "Wishing I had taken a bigger chance." Laura Probert #NimbleQuotes
# Be rooted in belief. "Give me a place to stand, and I will move the Earth." Archimedes #NimbleQuotes
# Think and write but always have perspective, "Don't let a little dispute injure a great friendship." Dalai Lama #NimbleQuotes
# Where did you begin? "Home is where one starts from." T.S. Eliot #NimbleQuotes
# Think yourself great. "What we think, we become." Buddha #NimbleQuotes
# Promise yourself: "Never, never, never give up." Winston Churchill #NimbleQuotes
# Improve their lives to prosper. "A business is simply an idea to make other people's lives better." Richard Branson #NimbleQuotes
# Love your life! "It is not how much we have, but how much we enjoy, that makes happiness." Charles Spurgeon #NimbleQuotes
# Make each moment count. "Life can only be understood backwards; but it must be lived forwards." Søren Kierkegaard #NimbleQuotes
# An invaluable and unforgettable education. "Experience, travel - these are an education in themselves." Euripides #NimbleQuotes
# Choose to be happy. "No man is happy unless he believes he is." Publilius Syrus #NimbleQuotes
# After 12 hours in the #car on our way back to #losangeles we decided to check out the furthest… https://t.co/z7AL6NdNRZ
# Last night Sexy E👨🏻😍 and I took our boy 👦🏻 out for his first #guinness in #vancity 🇨🇦🇨🇦 (1st… https://t.co/B0bDaTNOe2
# Skeet #shooting 🔫 with my #fambam 👏🏻👏🏻 😍on this gorgeous #washington #state day on this 108 acre… https://t.co/UpDE6to2nP
# #huevosrancheros 🍳🍳 it's what's for #brunch 😍👌🏻🌈! Deeelightful!! #foodporn #food #food… https://t.co/qhnQBPgsma
# The #interior is just as #colorful 🌈 as the outside!! Love this little #breakfast #lunch #brunch… https://t.co/JNrN74boXJ
# #brunch time at the Home Skillet in #bellingham 👌🏻😍 with my boy 👦🏻! #lunch #breakfast… https://t.co/gUAvqiPmmY
# Hiked up to #marymerefalls 🌲🌲🌧yesterday with my boy 👦🏻👌🏻👌🏻 and notyourgrandmaschaplain 👩🏼!… https://t.co/0CXgO83nyU
# Evening #coffee pick me up driving through #washington #state @dutchbros #doubleshot… https://t.co/o0pwrjgPpb
# Late #lunch with my boy. Having a ball on our #roadtrip 🚗👌🏻 #foodstagram #food #foodporn… https://t.co/RmCDfaXEbA
# Perfect #post #workout #lunch of #bbq #salmon over #brownrice and #veggies with 🎃! Absolutely… https://t.co/hcMipUhsCQ
# My #reviews are up on the blog today, link in bio, for the #beverlyhills #md #products 💁🏼which… https://t.co/eRmJo2NHjz
# #ramen it's what's for #dinner 👌🏻👌🏻 Discovered a great ramen house near our apartment. We'll be… https://t.co/m0XzccWX8b
# Date night with Sexy E 😍👌🏻! #chicken #fig #brie on focaccia. Outstanding👏🏻👏🏻 #vancouver #vancity… https://t.co/GAWyxrvT3y
# My drive home 😍 back to #vancouver 👌🏻 Simply spectacular! #Washington #pacnorthwest #lifestyle… https://t.co/z36J8mlC8I
# So happy to have moved closer to my nieces and nephew whom I didn't get to visit that often. Now… https://t.co/0EBoUa3hTK
# My amazing nephew colinhiday poured and finished the concrete for the Dungeouness River Bridge!… https://t.co/N4Cy7tmIDp
# Morning #coffee ☕️rituals 🐾🐾 at the #dailygrindsequim 👌🏻 The Bro🐶 and Lucy🐶 awaiting their #dog… https://t.co/t8dNL8OSEZ
# Amazing late lunch with my #sister 👌🏻👌🏻 The #glutenfree #crabcake #salad with #beets was #yummy… https://t.co/YyqrMnQCuy

# %%
b

# %%
import pickle
with open("../../data/pan/corpus17.pickle", "rb") as f:
    corpus17 = pickle.load(f)

# %%
en17 = corpus17[corpus17['lang'] == 'en']

# %%
fen17 = en17[en17['gender'] == 'f']
men17 = en17[en17['gender'] == 'm']

# %%
from spacy.en import English

nlp = English()

# %%
corpus17 = corpus17[corpus17['lang'] == 'en']

# %%
corpus17['text'] = corpus17['text'].apply(lambda x: "\n".join(x))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# 3584  Did you tweet about the white GOP guy, @VP, be...  female  united states
# 3585  @HobbesGhirl not.  Gone for a scan with a spec...    male        ireland
# 3586  Just commented on @thejournal_ie: Ireland is e...  female        ireland
# 3587  Snow Day.\nIt's got me like... 😍😍😍\n•\nhttps:/...  female         canada
# 3588  @McDonalds I can't get enough of these #grandm...    male  united states
# 3589  Really liking this album! Been playing it at w...  female  great britain
# 3590  And suddenly California is all like, "Sweet! H...    male  united states
# 3591  @xGrumpyOldManx seems to have backfired then. ...    male  great britain
# 3592  @rodmickleburgh @JenStDen no Rod. City has/con...    male         canada
# 3593  Yes please 💕💕💕 https://t.co/FF6DS4H6Qa\n#handw...  female  great britain
# 3594  @Predictive_Hire thanks for following👍\n@lawre...    male      australia
# 3595  @LauraAnthony7 @UCBerkeley eooks likes lynch m...  female  united states
# 3596  @groubes such a classy player! Was awesome to ...    male      australia
# 3597  Great weekend spent with family! Thoroughly en...    male  united states
# 3598  @SavageFc602 @TellEmSteveDave he IS the disord...  female        ireland
# 3599  @HuntersRL He's a lovely tall drink of water. ...  female    new zealand
#
# [3600 rows x 5 columns]

# %%
texts = [x for x in corpus17['text']]

# %%
spd = []
for i, text in enumerate(texts):
    if i % 100 == 0:
        print("{} ".format(i), end="")
    spd.append(nlp(text))
# Out:
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500

# %%
def get_tags(sp):
    return ' '.join([x.tag_ for x in sp])

ttexts = [get_tags(x) for x in spd]
ys = [0 if g == "female" else 1 for g in corpus17['gender']]

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
word_vec = TfidfVectorizer(binary=True, ngram_range=(1,3))
char_vec = TfidfVectorizer(ngram_range=(3,6), analyzer='char')
classifier = LinearSVC()

# %%
def tag_text(spacy_text):
    return "{} \n {}".format(spacy_text, ' '.join([word.tag_ for word in spacy_text]))

# %%
tagged_texts = [tag_text(text) for text in spd]

# %%
tagged_texts[0]
# Out:
# "One to watch … \nAvailable on 10th Feb. https://t.co/l1FOX1Yg9O \n@kirkj @deleifd There are 3 complete sets in each box of batman minifigs. Find two others who want all the figs and buy a box between you. 🤘\n@deleifd If you have 1, 3, (maybe 5), 10 or 14, we can come to some arrangement. 👍\n@deleifd I've heard that numerous other toyworlds are still numbering, despite the warning. Damn it. I'm only after 6 of the 20.\nJust heard about a new Web Dev meetup in The Hutt. Spread the good word!\nhttps://t.co/BlgGNdGPUP \nHullo. Anyone have a travel rest pillow I could borrow for a long trip?\n@emstrx My face is one big ache after a dental visit. I'm off home to eat mush.\n@julianwoodhouse Thanks for that! \ncc @mr_orgue\nHmm, that’s just Wgtn. \nFor Hutt, try https://t.co/O5tuokOfcQ... &gt; Tap Layers icon (bottom left) &gt; Tap Tsunami Zone option. cc @mr_orgue\n@kirkj Thankyou Kirk! I’d seen the maps in your first link, but not this second one. \\m/ cc @mr_orgue\nAnyone know where I might find some decent resolution tsunami zone maps for Wellington &amp; Hutt?\ncc: @Koordinates\n@sereeena I’ve just put some Slayer on the stereo here. \n\n༼ノಠل͟ಠ༽ノ-︵-┻━┻\nStunned white guy retweets. https://t.co/0mVZ3RIlg4 \n@bpujji Someone very near and dear to me, who may or may not have wanted to be named.\nIntroduced someone to Lemon Jelly. Yussss (Highest five to @FredDeakin)\n@jarred Hi Faive.\n@jarred What the font is saying Harriet Display Italic (Bold?)\nStarted off the day with Freebird. Followed by Don’t Fear the Reaper. Up next: the entirety of Deep Purple’s Machine Head. #rockinprototypin\n@hellomisspotter Ahh, didn’t know you’d moved. Enjoy!\n@hellomisspotter CrossFit Hutt Valley (Petone/Alicetown border) is well recommended by folk I know well. Good community.\n@microsoftnz I was thinking more https://t.co/kscIMVlJxt \n@_d___d_ it's no actually all that great. Weather depending. 😉\n@theraromachine @_grafik Get these instead! https://t.co/iYXxtKhkgJ mmmmMmmmm.\n@lizyjoy There will be trouble ahead. This is going to embolden militant sorts.\nA lot of knee jerking on the tweets today. The surface pro video makes me really miss the drafting table. The MacBook Pro looks like fun.\n@nzjames It came with a copy of a starwars lego magazine available in the UK, that a friend kindly sent me. I’d like about 30 more myself!\nWelcomed a new addition to the family today. So cute! https://t.co/M2x06UzKQx \n@four_seven it's a mystery adventure thingy!\n@ActionFigured That's great! Liking your corners too. Good touch.\n@katedarby_ Heya. Are you still looking for a bestawards ticket? cc @KirstiGrant\n@nwmetro So you know, no sign of the free farmed ham. Just got told “No.”\n@BR4DY Congratulations on the Community Board position, fella. Very promising council vote too. Playing the long game 🤘\nLooking forward to getting out to the @DesignMeetupNZ DesignPro event tonight! I’ve not been out for aaaages. Well, since Steve Krug anyhow.\n@Sereeena not seeing the context for this. You okay?\n@sourcecraft Heh. Well spotted.\n@craighamnett you are correct in the sense that I'm not able to level up. Hugs for you 'n' G.\nPlaying @kerretta on the big speakers to kickstart the day in the office. Perfect.\n@aliseflannery Heya Alise. If you do need a hand with creative event stuff, I'd be keen to chat. Cheers :)\n@uxpaul @dafttom @femkesvs Three wonderful talented people. 😊\n@NWMetro ✋\nHere’s a customer vote for free-farmed/free-range ham in your deli.\n@dafttom I WANT THESE THINGS!! So cool.\n@reasonsto @uxpaul @femkesvs\nAfter yesterday’s specific hunger … the Yummly email today is bringing it home. https://t.co/pD7T6K95Js \n@hannahcooknz Heh, not been to the Colonial for years!\n@hannahcooknz I appreciate your fine eye for quality bacon though. :)\n@hannahcooknz Tasty bacon, tiny bread &amp; long way from me right now … :(\nWhere, o Wellington, are your fine bacon sandwiches?\n@jamesmacfie @jamiepenney End of an era! Thanks for being awesome during my time ther ...

# %%
from sklearn.pipeline import FeatureUnion

fu = FeatureUnion([
    ('word', word_vec),
    ('char', char_vec)
])

# %%
Xs = fu.fit_transform(tagged_texts)

# %%
Xs.shape
# Out:
# (3600, 16585575)

# %%
cross_val_score(classifier, Xs, ys, cv=5, n_jobs=-1)
# text + tag (concatenated) array([ 0.77638889,  0.76805556,  0.76944444,  0.75416667,  0.76666667])
# Out:
# array([ 0.775     ,  0.8       ,  0.78888889,  0.76944444,  0.81944444])
